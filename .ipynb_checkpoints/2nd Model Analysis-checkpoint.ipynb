# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy
import sklearn
import os
from sklearn.model_selection import train_test_split

# %%
def convert_to_categorical(time_str):
    hour = int(time_str.split(':')[0])
    
    if 0 <= hour < 3:
        return 'Late Night'
    elif 3 <= hour < 6:
        return 'Early Morning'
    elif 6 <= hour < 9:
        return 'Morning'
    elif 9 <= hour < 12:
        return 'Late Morning'
    elif 12 <= hour < 15:
        return 'Noon'
    elif 15 <= hour < 18:
        return 'Afternoon'
    elif 18 <= hour < 21:
        return 'Evening'
    else:
        return 'Night'

# %%
data = pd.read_csv("1_HOP.csv")

# %%
data.head()
# Out:
#   Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number Origin Airport  \
# 0           B6        2010-01-01             22      N608JB            JFK
# 1           B6        2010-01-01             44      N586JB            JFK
# 2           MQ        2010-01-01           4094      N610MQ            ORD
# 3           9E        2010-01-01           3818      89289E            DTW
# 4           B6        2010-01-01             42      N586JB            JFK
#
#   Scheduled Arrival Time  Scheduled Elapsed Time (Minutes) FLIGHT_STATUS  \
# 0                  00:01                                76          LATE
# 1                  08:55                                75          LATE
# 2                  11:20                               100        ONTIME
# 3                  11:44                                84          LATE
# 4                  11:52                                71          LATE
#
#    month  day  season PREV_STAT
# 0      1    1  winter    ONTIME
# 1      1    1  winter      LATE
# 2      1    1  winter      LATE
# 3      1    1  winter    ONTIME
# 4      1    1  winter      LATE

# %%
data['SCHED_ARRV_TIME_CAT'] = data['Scheduled Arrival Time'].apply(convert_to_categorical)

# %%
data.head()
# Out:
#   Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number Origin Airport  \
# 0           B6        2010-01-01             22      N608JB            JFK
# 1           B6        2010-01-01             44      N586JB            JFK
# 2           MQ        2010-01-01           4094      N610MQ            ORD
# 3           9E        2010-01-01           3818      89289E            DTW
# 4           B6        2010-01-01             42      N586JB            JFK
#
#   Scheduled Arrival Time  Scheduled Elapsed Time (Minutes) FLIGHT_STATUS  \
# 0                  00:01                                76          LATE
# 1                  08:55                                75          LATE
# 2                  11:20                               100        ONTIME
# 3                  11:44                                84          LATE
# 4                  11:52                                71          LATE
#
#    month  day  season PREV_STAT SCHED_ARRV_TIME_CAT
# 0      1    1  winter    ONTIME          Late Night
# 1      1    1  winter      LATE             Morning
# 2      1    1  winter      LATE        Late Morning
# 3      1    1  winter    ONTIME        Late Morning
# 4      1    1  winter      LATE        Late Morning

# %% [markdown]
# # Processing For Prediction Starts Here -- TARGET CONVERTED TO CATEGORICAL

# %%
df = data.drop(columns=['Date (MM/DD/YYYY)', 'Flight Number','Tail Number', 'Scheduled Arrival Time'])

# %%
df.head()
# Out:
#   Carrier Code Origin Airport  Scheduled Elapsed Time (Minutes) FLIGHT_STATUS  \
# 0           B6            JFK                                76          LATE
# 1           B6            JFK                                75          LATE
# 2           MQ            ORD                               100        ONTIME
# 3           9E            DTW                                84          LATE
# 4           B6            JFK                                71          LATE
#
#    month  day  season PREV_STAT SCHED_ARRV_TIME_CAT
# 0      1    1  winter    ONTIME          Late Night
# 1      1    1  winter      LATE             Morning
# 2      1    1  winter      LATE        Late Morning
# 3      1    1  winter    ONTIME        Late Morning
# 4      1    1  winter      LATE        Late Morning

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import OneHotEncoder

class MultiColumnOneHotEncoder(BaseEstimator, TransformerMixin):
    def __init__(self, columns=None):
        self.columns = columns
        self.encoder = None

    def fit(self, X, y=None):
        self.encoder = OneHotEncoder(sparse_output=False, drop='first')
        self.encoder.fit(X[self.columns])
        return self

    def transform(self, X):
        X_encoded = X.copy()
        encoded_data = self.encoder.transform(X[self.columns])
        encoded_df = pd.DataFrame(encoded_data, columns=self.encoder.get_feature_names_out(self.columns), index=X.index)
        
        # Drop the original columns
        X_encoded = X_encoded.drop(columns=self.columns)
        
        # Concatenate the encoded DataFrame with the original DataFrame, preserving the index
        X_encoded = pd.concat([X_encoded, encoded_df], axis=1)
        return X_encoded

    def fit_transform(self, X, y=None):
        self.fit(X)
        return self.transform(X)

# %%
df.columns
# Out:
# Index(['Carrier Code', 'Origin Airport', 'Scheduled Elapsed Time (Minutes)',
#        'FLIGHT_STATUS', 'month', 'day', 'season', 'PREV_STAT',
#        'SCHED_ARRV_TIME_CAT'],
#       dtype='object')

# %%
df['FLIGHT_STATUS'].value_counts()
# Out:
# FLIGHT_STATUS
# EARLY     52242
# LATE      34107
# ONTIME    27326
# Name: count, dtype: int64

# %%
encoder = MultiColumnOneHotEncoder(columns=['Carrier Code', 'Origin Airport','season', 'SCHED_ARRV_TIME_CAT', 'month','PREV_STAT'])

# %%
encoded_data = encoder.fit_transform(df.drop(columns=['FLIGHT_STATUS']))

# %%
trainX, testX, trainY, testY = train_test_split(
    encoded_data,
    df['FLIGHT_STATUS'], 
    test_size=0.2, 
    random_state=947,
    stratify=df['FLIGHT_STATUS']
)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()


enc_trainX = pd.DataFrame(scaler.fit_transform(trainX), index=trainX.index, columns=trainX.columns)
enc_testX = pd.DataFrame(scaler.transform(testX), index=testX.index, columns=testX.columns)

# %%
enc_trainX
# Out:
#         Scheduled Elapsed Time (Minutes)       day  Carrier Code_AA  \
# 97066                           0.083886 -0.537515         4.176871
# 60085                           0.117531 -1.678626        -0.239414
# 4849                           -1.160986 -0.651626        -0.239414
# 52868                           1.968016 -0.081070        -0.239414
# 10072                           0.891370  1.402375        -0.239414
# ...                                  ...       ...              ...
# 1129                           -0.689953 -0.423403        -0.239414
# 22544                           0.050241  0.375375        -0.239414
# 37772                          -0.790889  1.744709        -0.239414
# 113539                          0.857725  1.402375        -0.239414
# 63903                          -0.891824 -0.081070        -0.239414
#
#         Carrier Code_B6  Carrier Code_DL  Carrier Code_EV  Carrier Code_F9  \
# 97066         -0.452203        -0.350921        -0.345383        -0.127692
# 60085         -0.452203        -0.350921        -0.345383        -0.127692
# 4849          -0.452203        -0.350921        -0.345383        -0.127692
# 52868          2.211397        -0.350921        -0.345383        -0.127692
# 10072         -0.452203        -0.350921         2.895340        -0.127692
# ...                 ...              ...              ...              ...
# 1129          -0.452203        -0.350921        -0.345383        -0.127692
# 22544         -0.452203        -0.350921        -0.345383        -0.127692
# 37772         -0.452203        -0.350921         2.895340        -0.127692
# 113539        -0.452203         2.849640        -0.345383        -0.127692
# 63903         -0.452203        -0.350921        -0.345383        -0.127692
#
#         Carrier Code_G4  Carrier Code_MQ  Carrier Code_OH  ...   month_5  \
# 97066         -0.152656        -0.341501        -0.225969  ... -0.306747
# 60085         -0.152656        -0.341501        -0.225969  ... -0.306747
# 4849          -0.152656        -0.341501        -0.225969  ... -0.306747
# 52868         -0.152656        -0.341501        -0.225969  ... -0.306747
# 10072         -0.152656        -0.341501        -0.225969  ... -0.306747
# ...                 ...              ...              ...  ...       ...
# 1129          -0.152656        -0.341501         4.425378  ... -0.306747
# 22544         -0.152656         2.928250        -0.225969  ... -0.306747
# 37772         -0.152656        -0.341501        -0.225969  ... -0.306747
# 113539        -0.152656        -0.341501        -0.225969  ... -0.306747
# 63903         -0.152656        -0.341501         4.425378  ...  3.260011
#
#          month_6   month_7   month_8   month_9  month_10  month_11  month_12  \
# 97066  -0.301439 -0.306619 -0.308504 -0.302913  3.196261 -0.305695 -0.300091
# 60085  -0.301439 -0.306619 -0.308504 -0.302913 -0.312866 -0.305695 -0.300091
# 4849    3.317421 -0.306619 -0.308504 -0.302913 -0.312866 -0.305695 -0.300091
# 52868  -0.301439 -0.306619 -0.308504 -0.302913 -0.312866 -0.305695 -0.300091
# 10072  -0.301439 -0.306619 -0.308504 -0.302913 -0.312866  3.271235 -0.300091
# ...          ...       ...       ...       ...       ...       ...       ...
# 1129   -0.301439 -0.306619 -0.308504 -0.302913 -0.312866 -0.305695 -0.300091
# 22544  -0.301439 -0.306619  3.241454 -0.302913 -0.312866 -0.305695 -0.300091
# 37772  -0.301439  3.261380 -0.308504 -0.302913 -0.312866 -0.305695 -0.300091
# 113539 -0.301439 -0.306619 -0.308504 -0.302913 -0.312866 -0.305695  3.332319
# 63903  -0.301439 -0.306619 -0.308504 -0.302913 -0.312866 -0.305695 -0.300091
#
#         PREV_STAT_LATE  PREV_STAT_ONTIME
# 97066        -0.654071         -0.562754
# 60085        -0.654071         -0.562754
# 4849          1.528886         -0.562754
# 52868        -0.654071          1.776974
# 10072        -0.654071          1.776974
# ...                ...               ...
# 1129         -0.654071         -0.562754
# 22544        -0.654071         -0.562754
# 37772        -0.654071          1.776974
# 113539       -0.654071         -0.562754
# 63903        -0.654071          1.776974
#
# [90940 rows x 72 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

def logistic_regression_classification(trainX, trainY, testX, testY, penalty='l2', C=1.0, max_iter=1000, solver='lbfgs'):
    """
    Perform classification using Regularized Logistic Regression for three-class prediction.
    
    Parameters:
        trainX (DataFrame or array-like): Features for training.
        trainY (Series or array-like): Target variable for training.
        testX (DataFrame or array-like): Features for testing.
        testY (Series or array-like): Target variable for testing.
        penalty (str, optional): Regularization type ('l1' for Lasso, 'l2' for Ridge). Default is 'l2'.
        C (float, optional): Inverse of regularization strength; smaller values specify stronger regularization. Default is 1.0.
        max_iter (int, optional): Maximum number of iterations for optimization algorithm. Default is 1000.
        solver (str, optional): Optimization algorithm to use ('lbfgs', 'sag', 'saga', etc.). Default is 'lbfgs'.
        
    Returns:
        dict: Dictionary containing accuracy score and classification report.
    """
    # Get unique target names
    target_names = trainY.unique() if isinstance(trainY, pd.Series) else testY.unique()
    
    # Initialize and train the Logistic Regression model
    model = LogisticRegression(penalty=penalty, C=C, max_iter=max_iter, solver=solver, verbose=1 if max_iter > 300 else 0)
    model.fit(trainX, trainY)
    
    # Predict on the testing set
    testY_pred = model.predict(testX)
    
    # Calculate accuracy score
    accuracy = accuracy_score(testY, testY_pred)
    
    # Generate classification report
    report = classification_report(testY, testY_pred, target_names=target_names, output_dict=True)
    
    results = {
        'accuracy': accuracy,
        'classification_report': report
    }
    
    return results

# %%
report = logistic_regression_classification(enc_trainX, trainY, enc_testX, testY, max_iter=1500, solver='saga')
print(report)
# Out:
# Epoch 1, change: 1.00000000
# Epoch 2, change: 0.23175497
# Epoch 3, change: 0.19071831
# Epoch 4, change: 0.16084113
# Epoch 5, change: 0.13650038
# Epoch 6, change: 0.13859023
# Epoch 7, change: 0.13035760
# Epoch 8, change: 0.11362027
# Epoch 9, change: 0.09916259
# Epoch 10, change: 0.08797052
# Epoch 11, change: 0.07878338
# Epoch 12, change: 0.07176631
# Epoch 13, change: 0.06535176
# Epoch 14, change: 0.06008405
# Epoch 15, change: 0.05545839
# Epoch 16, change: 0.05145380
# Epoch 17, change: 0.04798212
# Epoch 18, change: 0.04485332
# Epoch 19, change: 0.04209662
# Epoch 20, change: 0.03967373
# Epoch 21, change: 0.03744424
# Epoch 22, change: 0.03545458
# Epoch 23, change: 0.03363509
# Epoch 24, change: 0.03198471
# Epoch 25, change: 0.03047448
# Epoch 26, change: 0.02908091
# Epoch 27, change: 0.02779029
# Epoch 28, change: 0.02658743
# Epoch 29, change: 0.02551903
# Epoch 30, change: 0.02450138
# Epoch 31, change: 0.02355231
# Epoch 32, change: 0.02266760
# Epoch 33, change: 0.02184861
# Epoch 34, change: 0.02107164
# Epoch 35, change: 0.02032884
# Epoch 36, change: 0.01964902
# Epoch 37, change: 0.01902154
# Epoch 38, change: 0.01839665
# Epoch 39, change: 0.01784630
# Epoch 40, change: 0.01729420
# Epoch 41, change: 0.01678973
# Epoch 42, change: 0.01629786
# Epoch 43, change: 0.01583948
# Epoch 44, change: 0.01538467
# Epoch 45, change: 0.01496555
# Epoch 46, change: 0.01457856
# Epoch 47, change: 0.01419816
# Epoch 48, change: 0.01383633
# Epoch 49, change: 0.01349018
# Epoch 50, change: 0.01314302
# Epoch 51, change: 0.01283415
# Epoch 52, change: 0.01252789
# Epoch 53, change: 0.01224786
# Epoch 54, change: 0.01195222
# Epoch 55, change: 0.01168348
# Epoch 56, change: 0.01143316
# Epoch 57, change: 0.01117883
# Epoch 58, change: 0.01094028
# Epoch 59, change: 0.01070765
# Epoch 60, change: 0.01047782
# Epoch 61, change: 0.01027245
# Epoch 62, change: 0.01006416
# Epoch 63, change: 0.00987576
# Epoch 64, change: 0.00967173
# Epoch 65, change: 0.00947904
# Epoch 66, change: 0.00930226
# Epoch 67, change: 0.00912442
# Epoch 68, change: 0.00896123
# Epoch 69, change: 0.00879247
# Epoch 70, change: 0.00864069
# Epoch 71, change: 0.00848141
# Epoch 72, change: 0.00833949
# Epoch 73, change: 0.00818336
# Epoch 74, change: 0.00804093
# Epoch 75, change: 0.00790729
# Epoch 76, change: 0.00777319
# Epoch 77, change: 0.00764891
# Epoch 78, change: 0.00752722
# Epoch 79, change: 0.00739953
# Epoch 80, change: 0.00728014
# Epoch 81, change: 0.00716230
# Epoch 82, change: 0.00705165
# Epoch 83, change: 0.00694318
# Epoch 84, change: 0.00683468
# Epoch 85, change: 0.00672810
# Epoch 86, change: 0.00662564
# Epoch 87, change: 0.00652822
# Epoch 88, change: 0.00643132
# Epoch 89, change: 0.00633843
# Epoch 90, change: 0.00624634
# Epoch 91, change: 0.00615039
# Epoch 92, change: 0.00606255
# Epoch 93, change: 0.00598054
# Epoch 94, change: 0.00589575
# Epoch 95, change: 0.00581345
# Epoch 96, change: 0.00573029
# Epoch 97, change: 0.00565025
# Epoch 98, change: 0.00557702
# Epoch 99, change: 0.00550453
# Epoch 100, change: 0.00542401
# Epoch 101, change: 0.00535651
# Epoch 102, change: 0.00528299
# Epoch 103, change: 0.00521492
# Epoch 104, change: 0.00514426
# Epoch 105, change: 0.00508075
# Epoch 106, change: 0.00501255
# Epoch 107, change: 0.00495182
# Epoch 108, change: 0.00488474
# Epoch 109, change: 0.00483110
# Epoch 110, change: 0.00476428
# Epoch 111, change: 0.00470678
# Epoch 112, change: 0.00464475
# Epoch 113, change: 0.00459475
# Epoch 114, change: 0.00453242
# Epoch 115, change: 0.00447917
# Epoch 116, change: 0.00442860
# Epoch 117, change: 0.00437567
# Epoch 118, change: 0.00431987
# Epoch 119, change: 0.00427359
# Epoch 120, change: 0.00421571
# Epoch 121, change: 0.00417341
# Epoch 122, change: 0.00412054
# Epoch 123, change: 0.00407524
# Epoch 124, change: 0.00402941
# Epoch 125, change: 0.00397774
# Epoch 126, change: 0.00393893
# Epoch 127, change: 0.00389337
# Epoch 128, change: 0.00384696
# Epoch 129, change: 0.00380490
# Epoch 130, change: 0.00376356
# Epoch 131, change: 0.00372005
# Epoch 132, change: 0.00368019
# Epoch 133, change: 0.00363997
# Epoch 134, change: 0.00359791
# Epoch 135, change: 0.00356046
# Epoch 136, change: 0.00352254
# Epoch 137, change: 0.00348330
# Epoch 138, change: 0.00344547
# Epoch 139, change: 0.00340903
# Epoch 140, change: 0.00337507
# Epoch 141, change: 0.00333560
# Epoch 142, change: 0.00330232
# Epoch 143, change: 0.00326971
# Epoch 144, change: 0.00323103
# Epoch 145, change: 0.00319861
# Epoch 146, change: 0.00316590
# Epoch 147, change: 0.00313383
# Epoch 148, change: 0.00310304
# Epoch 149, change: 0.00306833
# Epoch 150, change: 0.00303907
# Epoch 151, change: 0.00300732
# Epoch 152, change: 0.00297435
# Epoch 153, change: 0.00294769
# Epoch 154, change: 0.00291865
# Epoch 155, change: 0.00288813
# Epoch 156, change: 0.00285817
# Epoch 157, change: 0.00283155
# Epoch 158, change: 0.00280344
# Epoch 159, change: 0.00277453
# Epoch 160, change: 0.00274815
# Epoch 161, change: 0.00271738
# Epoch 162, change: 0.00269504
# Epoch 163, change: 0.00266827
# Epoch 164, change: 0.00264263
# Epoch 165, change: 0.00261412
# Epoch 166, change: 0.00259049
# Epoch 167, change: 0.00256571
# Epoch 168, change: 0.00254227
# Epoch 169, change: 0.00251775
# Epoch 170, change: 0.00249342
# Epoch 171, change: 0.00247037
# Epoch 172, change: 0.00244562
# Epoch 173, change: 0.00242052
# Epoch 174, change: 0.00239882
# Epoch 175, change: 0.00237872
# Epoch 176, change: 0.00235558
# Epoch 177, change: 0.00233467
# Epoch 178, change: 0.00231112
# Epoch 179, change: 0.00228972
# Epoch 180, change: 0.00227024
# Epoch 181, change: 0.00224549
# Epoch 182, change: 0.00222826
# Epoch 183, change: 0.00220598
# Epoch 184, change: 0.00218628
# Epoch 185, change: 0.00216599
# Epoch 186, change: 0.00214787
# Epoch 187, change: 0.00212750
# Epoch 188, change: 0.00210628
# Epoch 189, change: 0.00208833
# Epoch 190, change: 0.00207057
# Epoch 191, change: 0.00205263
# Epoch 192, change: 0.00203287
# Epoch 193, change: 0.00201556
# Epoch 194, change: 0.00199669
# Epoch 195, change: 0.00197986
# Epoch 196, change: 0.00196071
# Epoch 197, change: 0.00194458
# Epoch 198, change: 0.00192725
# Epoch 199, change: 0.00191115
# Epoch 200, change: 0.00189212
# Epoch 201, change: 0.00187724
# Epoch 202, change: 0.00186024
# Epoch 203, change: 0.00184374
# Epoch 204, change: 0.00182801
# Epoch 205, change: 0.00181109
# Epoch 206, change: 0.00179718
# Epoch 207, change: 0.00178078
# Epoch 208, change: 0.00176562
# Epoch 209, change: 0.00174963
# Epoch 210, change: 0.00173622
# Epoch 211, change: 0.00171933
# Epoch 212, change: 0.00170546
# Epoch 213, change: 0.00168862
# Epoch 214, change: 0.00167703
# Epoch 215, change: 0.00166267
# Epoch 216, change: 0.00164709
# Epoch 217, change: 0.00163349
# Epoch 218, change: 0.00162070
# Epoch 219, change: 0.00160649
# Epoch 220, change: 0.00159220
# Epoch 221, change: 0.00157863
# Epoch 222, change: 0.00156709
# Epoch 223, change: 0.00155340
# Epoch 224, change: 0.00153855
# Epoch 225, change: 0.00152738
# Epoch 226, change: 0.00151438
# Epoch 227, change: 0.00150244
# Epoch 228, change: 0.00148850
# Epoch 229, change: 0.00147735
# Epoch 230, change: 0.00146464
# Epoch 231, change: 0.00145219
# Epoch 232, change: 0.00144096
# Epoch 233, change: 0.00142887
# Epoch 234, change: 0.00141627
# Epoch 235, change: 0.00140567
# Epoch 236, change: 0.00139441
# Epoch 237, change: 0.00138316
# Epoch 238, change: 0.00137024
# Epoch 239, change: 0.00135982
# Epoch 240, change: 0.00134855
# Epoch 241, change: 0.00133683
# Epoch 242, change: 0.00132698
# Epoch 243, change: 0.00131594
# Epoch 244, change: 0.00130561
# Epoch 245, change: 0.00129477
# Epoch 246, change: 0.00128419
# Epoch 247, change: 0.00127395
# Epoch 248, change: 0.00126372
# Epoch 249, change: 0.00125417
# Epoch 250, change: 0.00124423
# Epoch 251, change: 0.00123358
# Epoch 252, change: 0.00122396
# Epoch 253, change: 0.00121347
# Epoch 254, change: 0.00120367
# Epoch 255, change: 0.00119581
# Epoch 256, change: 0.00118542
# Epoch 257, change: 0.00117585
# Epoch 258, change: 0.00116690
# Epoch 259, change: 0.00115758
# Epoch 260, change: 0.00114817
# Epoch 261, change: 0.00113887
# Epoch 262, change: 0.00113020
# Epoch 263, change: 0.00112125
# Epoch 264, change: 0.00111215
# Epoch 265, change: 0.00110362
# Epoch 266, change: 0.00109558
# Epoch 267, change: 0.00108633
# Epoch 268, change: 0.00107793
# Epoch 269, change: 0.00106946
# Epoch 270, change: 0.00106121
# Epoch 271, change: 0.00105340
# Epoch 272, change: 0.00104472
# Epoch 273, change: 0.00103673
# Epoch 274, change: 0.00102849
# Epoch 275, change: 0.00102083
# Epoch 276, change: 0.00101247
# Epoch 277, change: 0.00100452
# Epoch 278, change: 0.00099737
# Epoch 279, change: 0.00098958
# Epoch 280, change: 0.00098192
# Epoch 281, change: 0.00097417
# Epoch 282, change: 0.00096671
# Epoch 283, change: 0.00095944
# Epoch 284, change: 0.00095220
# Epoch 285, change: 0.00094416
# Epoch 286, change: 0.00093692
# Epoch 287, change: 0.00093092
# Epoch 288, change: 0.00092277
# Epoch 289, change: 0.00091685
# Epoch 290, change: 0.00090914
# Epoch 291, change: 0.00090225
# Epoch 292, change: 0.00089594
# Epoch 293, change: 0.00088844
# Epoch 294, change: 0.00088207
# Epoch 295, change: 0.00087473
# Epoch 296, change: 0.00086890
# Epoch 297, change: 0.00086244
# Epoch 298, change: 0.00085591
# Epoch 299, change: 0.00084885
# Epoch 300, change: 0.00084253
# Epoch 301, change: 0.00083650
# Epoch 302, change: 0.00082987
# Epoch 303, change: 0.00082403
# Epoch 304, change: 0.00081765
# Epoch 305, change: 0.00081194
# Epoch 306, change: 0.00080473
# Epoch 307, change: 0.00079941
# Epoch 308, change: 0.00079308
# Epoch 309, change: 0.00078756
# Epoch 310, change: 0.00078131
# Epoch 311, change: 0.00077552
# Epoch 312, change: 0.00077026
# Epoch 313, change: 0.00076382
# Epoch 314, change: 0.00075927
# Epoch 315, change: 0.00075290
# Epoch 316, change: 0.00074687
# Epoch 317, change: 0.00074229
# Epoch 318, change: 0.00073619
# Epoch 319, change: 0.00073114
# Epoch 320, change: 0.00072553
# Epoch 321, change: 0.00072007
# Epoch 322, change: 0.00071527
# Epoch 323, change: 0.00070953
# Epoch 324, change: 0.00070437
# Epoch 325, change: 0.00069865
# Epoch 326, change: 0.00069375
# Epoch 327, change: 0.00068935
# Epoch 328, change: 0.00068360
# Epoch 329, change: 0.00067847
# Epoch 330, change: 0.00067453
# Epoch 331, change: 0.00066881
# Epoch 332, change: 0.00066388
# Epoch 333, change: 0.00065920
# Epoch 334, change: 0.00065449
# Epoch 335, change: 0.00064912
# Epoch 336, change: 0.00064506
# Epoch 337, change: 0.00064031
# Epoch 338, change: 0.00063558
# Epoch 339, change: 0.00063063
# Epoch 340, change: 0.00062615
# Epoch 341, change: 0.00062181
# Epoch 342, change: 0.00061738
# Epoch 343, change: 0.00061268
# Epoch 344, change: 0.00060818
# Epoch 345, change: 0.00060446
# Epoch 346, change: 0.00059941
# Epoch 347, change: 0.00059516
# Epoch 348, change: 0.00059088
# Epoch 349, change: 0.00058664
# Epoch 350, change: 0.00058277
# Epoch 351, change: 0.00057799
# Epoch 352, change: 0.00057388
# Epoch 353, change: 0.00057028
# Epoch 354, change: 0.00056540
# Epoch 355, change: 0.00056216
# Epoch 356, change: 0.00055738
# Epoch 357, change: 0.00055361
# Epoch 358, change: 0.00055014
# Epoch 359, change: 0.00054613
# Epoch 360, change: 0.00054192
# Epoch 361, change: 0.00053781
# Epoch 362, change: 0.00053397
# Epoch 363, change: 0.00053029
# Epoch 364, change: 0.00052679
# Epoch 365, change: 0.00052312
# Epoch 366, change: 0.00051916
# Epoch 367, change: 0.00051488
# Epoch 368, change: 0.00051211
# Epoch 369, change: 0.00050835
# Epoch 370, change: 0.00050450
# Epoch 371, change: 0.00050054
# Epoch 372, change: 0.00049755
# Epoch 373, change: 0.00049346
# Epoch 374, change: 0.00049046
# Epoch 375, change: 0.00048700
# Epoch 376, change: 0.00048319
# Epoch 377, change: 0.00048000
# Epoch 378, change: 0.00047653
# Epoch 379, change: 0.00047265
# Epoch 380, change: 0.00046983
# Epoch 381, change: 0.00046708
# Epoch 382, change: 0.00046324
# Epoch 383, change: 0.00045971
# Epoch 384, change: 0.00045682
# Epoch 385, change: 0.00045327
# Epoch 386, change: 0.00045039
# Epoch 387, change: 0.00044729
# Epoch 388, change: 0.00044394
# Epoch 389, change: 0.00044072
# Epoch 390, change: 0.00043789
# Epoch 391, change: 0.00043462
# Epoch 392, change: 0.00043156
# Epoch 393, change: 0.00042852
# Epoch 394, change: 0.00042559
# Epoch 395, change: 0.00042229
# Epoch 396, change: 0.00042006
# Epoch 397, change: 0.00041657
# Epoch 398, change: 0.00041415
# Epoch 399, change: 0.00041104
# Epoch 400, change: 0.00040793
# Epoch 401, change: 0.00040534
# Epoch 402, change: 0.00040204
# Epoch 403, change: 0.00039939
# Epoch 404, change: 0.00039708
# Epoch 405, change: 0.00039403
# Epoch 406, change: 0.00039142
# Epoch 407, change: 0.00038837
# Epoch 408, change: 0.00038598
# Epoch 409, change: 0.00038304
# Epoch 410, change: 0.00038049
# Epoch 411, change: 0.00037788
# Epoch 412, change: 0.00037533
# Epoch 413, change: 0.00037268
# Epoch 414, change: 0.00036986
# Epoch 415, change: 0.00036742
# Epoch 416, change: 0.00036504
# Epoch 417, change: 0.00036257
# Epoch 418, change: 0.00035982
# Epoch 419, change: 0.00035747
# Epoch 420, change: 0.00035499
# Epoch 421, change: 0.00035265
# Epoch 422, change: 0.00034993
# Epoch 423, change: 0.00034765
# Epoch 424, change: 0.00034526
# Epoch 425, change: 0.00034259
# Epoch 426, change: 0.00034048
# Epoch 427, change: 0.00033825
# Epoch 428, change: 0.00033589
# Epoch 429, change: 0.00033319
# Epoch 430, change: 0.00033145
# Epoch 431, change: 0.00032881
# Epoch 432, change: 0.00032673
# Epoch 433, change: 0.00032449
# Epoch 434, change: 0.00032227
# Epoch 435, change: 0.00031995
# Epoch 436, change: 0.00031792
# Epoch 437, change: 0.00031548
# Epoch 438, change: 0.00031350
# Epoch 439, change: 0.00031140
# Epoch 440, change: 0.00030936
# Epoch 441, change: 0.00030699
# Epoch 442, change: 0.00030477
# Epoch 443, change: 0.00030284
# Epoch 444, change: 0.00030105
# Epoch 445, change: 0.00029866
# Epoch 446, change: 0.00029656
# Epoch 447, change: 0.00029453
# Epoch 448, change: 0.00029258
# Epoch 449, change: 0.00029067
# Epoch 450, change: 0.00028886
# Epoch 451, change: 0.00028683
# Epoch 452, change: 0.00028462
# Epoch 453, change: 0.00028282
# Epoch 454, change: 0.00028086
# Epoch 455, change: 0.00027895
# Epoch 456, change: 0.00027713
# Epoch 457, change: 0.00027523
# Epoch 458, change: 0.00027341
# Epoch 459, change: 0.00027141
# Epoch 460, change: 0.00026968
# Epoch 461, change: 0.00026763
# Epoch 462, change: 0.00026609
# Epoch 463, change: 0.00026413
# Epoch 464, change: 0.00026241
# Epoch 465, change: 0.00026058
# Epoch 466, change: 0.00025883
# Epoch 467, change: 0.00025711
# Epoch 468, change: 0.00025532
# Epoch 469, change: 0.00025357
# Epoch 470, change: 0.00025174
# Epoch 471, change: 0.00025031
# Epoch 472, change: 0.00024863
# Epoch 473, change: 0.00024677
# Epoch 474, change: 0.00024497
# Epoch 475, change: 0.00024346
# Epoch 476, change: 0.00024197
# Epoch 477, change: 0.00024027
# Epoch 478, change: 0.00023858
# Epoch 479, change: 0.00023705
# Epoch 480, change: 0.00023532
# Epoch 481, change: 0.00023372
# Epoch 482, change: 0.00023218
# Epoch 483, change: 0.00023069
# Epoch 484, change: 0.00022902
# Epoch 485, change: 0.00022753
# Epoch 486, change: 0.00022605
# Epoch 487, change: 0.00022447
# Epoch 488, change: 0.00022305
# Epoch 489, change: 0.00022152
# Epoch 490, change: 0.00022007
# Epoch 491, change: 0.00021842
# Epoch 492, change: 0.00021705
# Epoch 493, change: 0.00021563
# Epoch 494, change: 0.00021414
# Epoch 495, change: 0.00021272
# Epoch 496, change: 0.00021144
# Epoch 497, change: 0.00020970
# Epoch 498, change: 0.00020849
# Epoch 499, change: 0.00020725
# Epoch 500, change: 0.00020565
# Epoch 501, change: 0.00020424
# Epoch 502, change: 0.00020288
# Epoch 503, change: 0.00020171
# Epoch 504, change: 0.00020016
# Epoch 505, change: 0.00019906
# Epoch 506, change: 0.00019760
# Epoch 507, change: 0.00019617
# Epoch 508, change: 0.00019497
# Epoch 509, change: 0.00019367
# Epoch 510, change: 0.00019223
# Epoch 511, change: 0.00019112
# Epoch 512, change: 0.00018988
# Epoch 513, change: 0.00018844
# Epoch 514, change: 0.00018729
# Epoch 515, change: 0.00018606
# Epoch 516, change: 0.00018468
# Epoch 517, change: 0.00018360
# Epoch 518, change: 0.00018232
# Epoch 519, change: 0.00018108
# Epoch 520, change: 0.00017998
# Epoch 521, change: 0.00017876
# Epoch 522, change: 0.00017755
# Epoch 523, change: 0.00017638
# Epoch 524, change: 0.00017517
# Epoch 525, change: 0.00017402
# Epoch 526, change: 0.00017282
# Epoch 527, change: 0.00017170
# Epoch 528, change: 0.00017052
# Epoch 529, change: 0.00016942
# Epoch 530, change: 0.00016834
# Epoch 531, change: 0.00016720
# Epoch 532, change: 0.00016620
# Epoch 533, change: 0.00016497
# Epoch 534, change: 0.00016381
# Epoch 535, change: 0.00016289
# Epoch 536, change: 0.00016169
# Epoch 537, change: 0.00016061
# Epoch 538, change: 0.00015944
# Epoch 539, change: 0.00015861
# Epoch 540, change: 0.00015744
# Epoch 541, change: 0.00015647
# Epoch 542, change: 0.00015533
# Epoch 543, change: 0.00015450
# Epoch 544, change: 0.00015337
# Epoch 545, change: 0.00015237
# Epoch 546, change: 0.00015132
# Epoch 547, change: 0.00015026
# Epoch 548, change: 0.00014937
# Epoch 549, change: 0.00014834
# Epoch 550, change: 0.0convergence after 610 epochs took 75 seconds
# {'accuracy': 0.49360017594018035, 'classification_report': {'ONTIME': {'precision': 0.5163681651049697, 'recall': 0.8332854818642932, 'f1-score': 0.6376185419794222, 'support': 10449.0}, 'EARLY': {'precision': 0.43142500445871235, 'recall': 0.3546400820993989, 'f1-score': 0.3892822658513035, 'support': 6821.0}, 'LATE': {'precision': 0.3609022556390977, 'recall': 0.01756633119853614, 'f1-score': 0.03350200663060548, 'support': 5465.0}, 'accuracy': 0.49360017594018035, 'macro avg': {'precision': 0.4362318084009266, 'recall': 0.40183063172074274, 'f1-score': 0.35346760482044376, 'support': 22735.0}, 'weighted avg': {'precision': 0.4535127222195899, 'recall': 0.49360017594018035, 'f1-score': 0.4178957091159438, 'support': 22735.0}}}

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

def decision_tree_classification(trainX, trainY, testX, testY, criterion='gini', max_depth=None):
    """
    Perform classification using Decision Trees for three-class prediction.
    
    Parameters:
        trainX (DataFrame or array-like): Features for training.
        trainY (Series or array-like): Target variable for training.
        testX (DataFrame or array-like): Features for testing.
        testY (Series or array-like): Target variable for testing.
        criterion (str, optional): Criterion used to measure the quality of a split ('gini' or 'entropy'). Default is 'gini'.
        max_depth (int, optional): Maximum depth of the tree. If None, the tree is fully grown. Default is None.
        
    Returns:
        dict: Dictionary containing accuracy score and classification report.
    """
    # Get unique target names
    target_names = trainY.unique() if isinstance(trainY, pd.Series) else testY.unique()
    
    # Initialize and train the Decision Tree model
    model = DecisionTreeClassifier(criterion=criterion, max_depth=max_depth)
    model.fit(trainX, trainY)
    
    # Predict on the testing set
    testY_pred = model.predict(testX)
    
    # Calculate accuracy score
    accuracy = accuracy_score(testY, testY_pred)
    
    # Generate classification report
    report = classification_report(testY, testY_pred, target_names=target_names, output_dict=True)
    
    results = {
        'accuracy': accuracy,
        'classification_report': report
    }
    
    return results

# %%
decision_tree_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# {'accuracy': 0.41570266109522763,
#  'classification_report': {'ONTIME': {'precision': 0.5270668823137665,
#    'recall': 0.5301942769643028,
#    'f1-score': 0.5286259541984732,
#    'support': 10449.0},
#   'EARLY': {'precision': 0.3601290890421006,
#    'recall': 0.35991790060108486,
#    'f1-score': 0.36002346385100453,
#    'support': 6821.0},
#   'LATE': {'precision': 0.26928056223414093,
#    'recall': 0.26642268984446477,
#    'f1-score': 0.2678440029433407,
#    'support': 5465.0},
#   'accuracy': 0.41570266109522763,
#   'macro avg': {'precision': 0.385492177863336,
#    'recall': 0.3855116224699508,
#    'f1-score': 0.3854978069976061,
#    'support': 22735.0},
#   'weighted avg': {'precision': 0.41501564294094107,
#    'recall': 0.41570266109522763,
#    'f1-score': 0.4153551844483354,
#    'support': 22735.0}}}

# %%
from sklearn.metrics import accuracy_score, classification_report

from sklearn.preprocessing import LabelEncoder

def fit_and_evaluate(model, trainX, trainY, testX, testY):
    # Convert string labels to integers
    label_encoder = LabelEncoder()
    trainY_encoded = label_encoder.fit_transform(trainY)
    testY_encoded = label_encoder.transform(testY)
    
    model.fit(trainX, trainY_encoded)
    testY_pred = model.predict(testX)
    accuracy = accuracy_score(testY_encoded, testY_pred)
    report = classification_report(testY_encoded, testY_pred, output_dict=True)
    results = {'accuracy': accuracy, 'classification_report': report}
    return results

# Update other classification functions similarly...


# Random Forest
from sklearn.ensemble import RandomForestClassifier

def random_forest_classification(trainX, trainY, testX, testY, n_estimators=100, criterion='gini', max_depth=None):
    model = RandomForestClassifier(n_estimators=n_estimators, criterion=criterion, max_depth=max_depth)
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# Support Vector Machines (SVM)
from sklearn.svm import SVC

def svm_classification(trainX, trainY, testX, testY, kernel='rbf', C=1.0):
    model = SVC(kernel=kernel, C=C)
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# K-Nearest Neighbors (KNN)
from sklearn.neighbors import KNeighborsClassifier

def knn_classification(trainX, trainY, testX, testY, n_neighbors=5):
    model = KNeighborsClassifier(n_neighbors=n_neighbors)
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# Gradient Boosting Machines (GBM)
from sklearn.ensemble import GradientBoostingClassifier

def gbm_classification(trainX, trainY, testX, testY, n_estimators=100, learning_rate=0.1, max_depth=3):
    model = GradientBoostingClassifier(n_estimators=n_estimators, learning_rate=learning_rate, max_depth=max_depth)
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# Naive Bayes
from sklearn.naive_bayes import GaussianNB

def naive_bayes_classification(trainX, trainY, testX, testY):
    model = GaussianNB()
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# AdaBoost
from sklearn.ensemble import AdaBoostClassifier

def adaboost_classification(trainX, trainY, testX, testY, n_estimators=50, learning_rate=1.0):
    model = AdaBoostClassifier(n_estimators=n_estimators, learning_rate=learning_rate)
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# XGBoost
from xgboost import XGBClassifier

def xgboost_classification(trainX, trainY, testX, testY, n_estimators=100, learning_rate=0.1, max_depth=3):
    model = XGBClassifier(n_estimators=n_estimators, learning_rate=learning_rate, max_depth=max_depth)
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# %%
random_forest_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# {'accuracy': 0.4398504508467121,
#  'classification_report': {'0': {'precision': 0.5436850057772642,
#    'recall': 0.5854148722365776,
#    'f1-score': 0.563778801843318,
#    'support': 10449.0},
#   '1': {'precision': 0.3870185016681832,
#    'recall': 0.3741386893417388,
#    'f1-score': 0.3804696235557212,
#    'support': 6821.0},
#   '2': {'precision': 0.2721881390593047,
#    'recall': 0.2435498627630375,
#    'f1-score': 0.2570738773539353,
#    'support': 5465.0},
#   'accuracy': 0.4398504508467121,
#   'macro avg': {'precision': 0.4009638821682507,
#    'recall': 0.4010344747804513,
#    'f1-score': 0.40044076758432484,
#    'support': 22735.0},
#   'weighted avg': {'precision': 0.43141966154406913,
#    'recall': 0.4398504508467121,
#    'f1-score': 0.4350568173509417,
#    'support': 22735.0}}}

# %%
knn_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# {'accuracy': 0.4620628986144711,
#  'classification_report': {'0': {'precision': 0.5161491544219573,
#    'recall': 0.7126997798832424,
#    'f1-score': 0.5987056317080034,
#    'support': 10449.0},
#   '1': {'precision': 0.40034071550255534,
#    'recall': 0.3445242633045008,
#    'f1-score': 0.37034118666771726,
#    'support': 6821.0},
#   '2': {'precision': 0.2905211325400082,
#    'recall': 0.12955169258920401,
#    'f1-score': 0.1791951404707669,
#    'support': 5465.0},
#   'accuracy': 0.4620628986144711,
#   'macro avg': {'precision': 0.402337000821507,
#    'recall': 0.3955919119256491,
#    'f1-score': 0.38274731961549585,
#    'support': 22735.0},
#   'weighted avg': {'precision': 0.42716800194981774,
#    'recall': 0.4620628986144711,
#    'f1-score': 0.42935006917308854,
#    'support': 22735.0}}}

# %%
gbm_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# {'accuracy': 0.49298438530899497,
#  'classification_report': {'0': {'precision': 0.5038180429802552,
#    'recall': 0.8840080390467987,
#    'f1-score': 0.6418371955668276,
#    'support': 10449.0},
#   '1': {'precision': 0.4556012581659811,
#    'recall': 0.27605922885207446,
#    'f1-score': 0.3438013511046193,
#    'support': 6821.0},
#   '2': {'precision': 0.3283582089552239,
#    'recall': 0.016102470265324794,
#    'f1-score': 0.030699459270887842,
#    'support': 5465.0},
#   'accuracy': 0.49298438530899497,
#   'macro avg': {'precision': 0.42925917003382014,
#    'recall': 0.39205657938806593,
#    'f1-score': 0.3387793353141116,
#    'support': 22735.0},
#   'weighted avg': {'precision': 0.4471752155263313,
#    'recall': 0.49298438530899497,
#    'f1-score': 0.40551565503751014,
#    'support': 22735.0}}}

# %%
naive_bayes_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# {'accuracy': 0.2538376951836376,
#  'classification_report': {'0': {'precision': 0.579295154185022,
#    'recall': 0.025169872715092353,
#    'f1-score': 0.048243602678161975,
#    'support': 10449.0},
#   '1': {'precision': 0.3818544366899302,
#    'recall': 0.056150124615159065,
#    'f1-score': 0.09790388548057259,
#    'support': 6821.0},
#   '2': {'precision': 0.24085910329918225,
#    'recall': 0.9377859103385179,
#    'f1-score': 0.3832778671054108,
#    'support': 5465.0},
#   'accuracy': 0.2538376951836376,
#   'macro avg': {'precision': 0.40066956472471144,
#    'recall': 0.33970196922292306,
#    'f1-score': 0.17647511842138178,
#    'support': 22735.0},
#   'weighted avg': {'precision': 0.4387059238298368,
#    'recall': 0.2538376951836376,
#    'f1-score': 0.14367773701245523,
#    'support': 22735.0}}}

# %%
adaboost_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# /home/numan947/anaconda3/envs/mldl/lib/python3.9/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# {'accuracy': 0.4873982845832417,
#  'classification_report': {'0': {'precision': 0.5043590753135722,
#    'recall': 0.8581682457651449,
#    'f1-score': 0.6353266260450616,
#    'support': 10449.0},
#   '1': {'precision': 0.42781077206635265,
#    'recall': 0.30626007916727754,
#    'f1-score': 0.35697197539302805,
#    'support': 6821.0},
#   '2': {'precision': 0.3424657534246575,
#    'recall': 0.004574565416285453,
#    'f1-score': 0.00902853015529072,
#    'support': 5465.0},
#   'accuracy': 0.4873982845832417,
#   'macro avg': {'precision': 0.42487853360152744,
#    'recall': 0.389667630116236,
#    'f1-score': 0.3337757105311268,
#    'support': 22735.0},
#   'weighted avg': {'precision': 0.4424772639842472,
#    'recall': 0.4873982845832417,
#    'f1-score': 0.4012656554651135,
#    'support': 22735.0}}}

# %%
xgboost_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# {'accuracy': 0.4913129535957774,
#  'classification_report': {'0': {'precision': 0.500080416018871,
#    'recall': 0.8927170064120968,
#    'f1-score': 0.6410555975534328,
#    'support': 10449.0},
#   '1': {'precision': 0.4587203302373581,
#    'recall': 0.2606655915554904,
#    'f1-score': 0.33242965317378703,
#    'support': 6821.0},
#   '2': {'precision': 0.3106796116504854,
#    'recall': 0.01171088746569076,
#    'f1-score': 0.0225709751366602,
#    'support': 5465.0},
#   'accuracy': 0.4913129535957774,
#   'macro avg': {'precision': 0.42316011930223824,
#    'recall': 0.388364495144426,
#    'f1-score': 0.33201874195462666,
#    'support': 22735.0},
#   'weighted avg': {'precision': 0.44214364271828044,
#    'recall': 0.4913129535957774,
#    'f1-score': 0.39979076236006456,
#    'support': 22735.0}}}

# %%
model = DecisionTreeClassifier(criterion='entropy', max_features='log2')
res = fit_and_evaluate(model, enc_trainX, trainY, enc_testX, testY)
print(res)
# Out:
# {'accuracy': 0.42159665713657357, 'classification_report': {'0': {'precision': 0.5303030303030303, 'recall': 0.5459852617475357, 'f1-score': 0.5380298957891262, 'support': 10449.0}, '1': {'precision': 0.3672460293676955, 'recall': 0.3593314763231198, 'f1-score': 0.363245646535754, 'support': 6821.0}, '2': {'precision': 0.2694701112577786, 'recall': 0.2614821591948765, 'f1-score': 0.26541604754829123, 'support': 5465.0}, 'accuracy': 0.42159665713657357, 'macro avg': {'precision': 0.3890063903095015, 'recall': 0.3889329657551774, 'f1-score': 0.38889719662439043, 'support': 22735.0}, 'weighted avg': {'precision': 0.4186837777865482, 'recall': 0.42159665713657357, 'f1-score': 0.4200603314700845, 'support': 22735.0}}}

# %%
model = RandomForestClassifier(n_estimators=300)
res = fit_and_evaluate(model, enc_trainX, trainY, enc_testX, testY)
print(res)

# %%
model = XGBClassifier(
    colsample_bytree=0.7,enable_categorical=True,
    gamma=0.0, learning_rate=0.05, max_depth=20, 
    min_child_weight=1,n_estimators=300,
    n_jobs=3,objective='multi:softprob')
res = fit_and_evaluate(model, enc_trainX, trainY, enc_testX, testY)
print(res)

# %%
model = GradientBoostingClassifier(n_estimators=300, max_depth=20)
res = fit_and_evaluate(model, enc_trainX, trainY, enc_testX, testY)
print(res)

# %%
model = KNeighborsClassifier(n_neighbors=11)
res = fit_and_evaluate(model, enc_trainX, trainY, enc_testX, testY)
print(res)
