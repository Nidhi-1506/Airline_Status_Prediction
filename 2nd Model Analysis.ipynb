# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy
import sklearn
import os
from sklearn.model_selection import train_test_split

# %%
def convert_to_categorical(time_str):
    hour = int(time_str.split(':')[0])
    
    if 0 <= hour < 3:
        return 'Late Night'
    elif 3 <= hour < 6:
        return 'Early Morning'
    elif 6 <= hour < 9:
        return 'Morning'
    elif 9 <= hour < 12:
        return 'Late Morning'
    elif 12 <= hour < 15:
        return 'Noon'
    elif 15 <= hour < 18:
        return 'Afternoon'
    elif 18 <= hour < 21:
        return 'Evening'
    else:
        return 'Night'

# %% [markdown]
# # 1 HOP

# %%
data = pd.read_csv("1_HOP.csv")

# %%
data.head()
# Out:
#   Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number Origin Airport  \
# 0           B6        2010-01-01             22      N608JB            JFK
# 1           B6        2010-01-01             44      N586JB            JFK
# 2           MQ        2010-01-01           4094      N610MQ            ORD
# 3           9E        2010-01-01           3818      89289E            DTW
# 4           B6        2010-01-01             42      N586JB            JFK
#
#   Scheduled Arrival Time  Scheduled Elapsed Time (Minutes) FLIGHT_STATUS  \
# 0                  00:01                                76          LATE
# 1                  08:55                                75          LATE
# 2                  11:20                               100        ONTIME
# 3                  11:44                                84          LATE
# 4                  11:52                                71          LATE
#
#    month  day  season PREV_STAT
# 0      1    1  winter    ONTIME
# 1      1    1  winter      LATE
# 2      1    1  winter      LATE
# 3      1    1  winter    ONTIME
# 4      1    1  winter      LATE

# %%
data['SCHED_ARRV_TIME_CAT'] = data['Scheduled Arrival Time'].apply(convert_to_categorical)

# %%
data.head()
# Out:
#   Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number Origin Airport  \
# 0           B6        2010-01-01             22      N608JB            JFK
# 1           B6        2010-01-01             44      N586JB            JFK
# 2           MQ        2010-01-01           4094      N610MQ            ORD
# 3           9E        2010-01-01           3818      89289E            DTW
# 4           B6        2010-01-01             42      N586JB            JFK
#
#   Scheduled Arrival Time  Scheduled Elapsed Time (Minutes) FLIGHT_STATUS  \
# 0                  00:01                                76          LATE
# 1                  08:55                                75          LATE
# 2                  11:20                               100        ONTIME
# 3                  11:44                                84          LATE
# 4                  11:52                                71          LATE
#
#    month  day  season PREV_STAT SCHED_ARRV_TIME_CAT
# 0      1    1  winter    ONTIME          Late Night
# 1      1    1  winter      LATE             Morning
# 2      1    1  winter      LATE        Late Morning
# 3      1    1  winter    ONTIME        Late Morning
# 4      1    1  winter      LATE        Late Morning

# %%
df = data.drop(columns=['Date (MM/DD/YYYY)', 'Flight Number','Tail Number', 'Scheduled Arrival Time'])

# %%
df.head()
# Out:
#   Carrier Code Origin Airport  Scheduled Elapsed Time (Minutes) FLIGHT_STATUS  \
# 0           B6            JFK                                76          LATE
# 1           B6            JFK                                75          LATE
# 2           MQ            ORD                               100        ONTIME
# 3           9E            DTW                                84          LATE
# 4           B6            JFK                                71          LATE
#
#    month  day  season PREV_STAT SCHED_ARRV_TIME_CAT
# 0      1    1  winter    ONTIME          Late Night
# 1      1    1  winter      LATE             Morning
# 2      1    1  winter      LATE        Late Morning
# 3      1    1  winter    ONTIME        Late Morning
# 4      1    1  winter      LATE        Late Morning

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import OneHotEncoder

class MultiColumnOneHotEncoder(BaseEstimator, TransformerMixin):
    def __init__(self, columns=None):
        self.columns = columns
        self.encoder = None

    def fit(self, X, y=None):
        self.encoder = OneHotEncoder(sparse_output=False, drop='first')
        self.encoder.fit(X[self.columns])
        return self

    def transform(self, X):
        X_encoded = X.copy()
        encoded_data = self.encoder.transform(X[self.columns])
        encoded_df = pd.DataFrame(encoded_data, columns=self.encoder.get_feature_names_out(self.columns), index=X.index)
        
        # Drop the original columns
        X_encoded = X_encoded.drop(columns=self.columns)
        
        # Concatenate the encoded DataFrame with the original DataFrame, preserving the index
        X_encoded = pd.concat([X_encoded, encoded_df], axis=1)
        return X_encoded

    def fit_transform(self, X, y=None):
        self.fit(X)
        return self.transform(X)

# %%
df.columns
# Out:
# Index(['Carrier Code', 'Origin Airport', 'Scheduled Elapsed Time (Minutes)',
#        'FLIGHT_STATUS', 'month', 'day', 'season', 'PREV_STAT',
#        'SCHED_ARRV_TIME_CAT'],
#       dtype='object')

# %%
df['FLIGHT_STATUS'].value_counts()
# Out:
# FLIGHT_STATUS
# EARLY     52242
# LATE      34107
# ONTIME    27326
# Name: count, dtype: int64

# %%
encoder = MultiColumnOneHotEncoder(columns=['Carrier Code', 'Origin Airport','season', 'SCHED_ARRV_TIME_CAT', 'month','PREV_STAT'])

# %%
encoded_data = encoder.fit_transform(df.drop(columns=['FLIGHT_STATUS']))

# %%
trainX, testX, trainY, testY = train_test_split(
    encoded_data,
    df['FLIGHT_STATUS'], 
    test_size=0.2, 
    random_state=947,
    stratify=df['FLIGHT_STATUS']
)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()


enc_trainX = pd.DataFrame(scaler.fit_transform(trainX), index=trainX.index, columns=trainX.columns)
enc_testX = pd.DataFrame(scaler.transform(testX), index=testX.index, columns=testX.columns)

# %%
enc_trainX
# Out:
#         Scheduled Elapsed Time (Minutes)       day  Carrier Code_AA  \
# 97066                           0.083886 -0.537515         4.176871
# 60085                           0.117531 -1.678626        -0.239414
# 4849                           -1.160986 -0.651626        -0.239414
# 52868                           1.968016 -0.081070        -0.239414
# 10072                           0.891370  1.402375        -0.239414
# ...                                  ...       ...              ...
# 1129                           -0.689953 -0.423403        -0.239414
# 22544                           0.050241  0.375375        -0.239414
# 37772                          -0.790889  1.744709        -0.239414
# 113539                          0.857725  1.402375        -0.239414
# 63903                          -0.891824 -0.081070        -0.239414
#
#         Carrier Code_B6  Carrier Code_DL  Carrier Code_EV  Carrier Code_F9  \
# 97066         -0.452203        -0.350921        -0.345383        -0.127692
# 60085         -0.452203        -0.350921        -0.345383        -0.127692
# 4849          -0.452203        -0.350921        -0.345383        -0.127692
# 52868          2.211397        -0.350921        -0.345383        -0.127692
# 10072         -0.452203        -0.350921         2.895340        -0.127692
# ...                 ...              ...              ...              ...
# 1129          -0.452203        -0.350921        -0.345383        -0.127692
# 22544         -0.452203        -0.350921        -0.345383        -0.127692
# 37772         -0.452203        -0.350921         2.895340        -0.127692
# 113539        -0.452203         2.849640        -0.345383        -0.127692
# 63903         -0.452203        -0.350921        -0.345383        -0.127692
#
#         Carrier Code_G4  Carrier Code_MQ  Carrier Code_OH  ...   month_5  \
# 97066         -0.152656        -0.341501        -0.225969  ... -0.306747
# 60085         -0.152656        -0.341501        -0.225969  ... -0.306747
# 4849          -0.152656        -0.341501        -0.225969  ... -0.306747
# 52868         -0.152656        -0.341501        -0.225969  ... -0.306747
# 10072         -0.152656        -0.341501        -0.225969  ... -0.306747
# ...                 ...              ...              ...  ...       ...
# 1129          -0.152656        -0.341501         4.425378  ... -0.306747
# 22544         -0.152656         2.928250        -0.225969  ... -0.306747
# 37772         -0.152656        -0.341501        -0.225969  ... -0.306747
# 113539        -0.152656        -0.341501        -0.225969  ... -0.306747
# 63903         -0.152656        -0.341501         4.425378  ...  3.260011
#
#          month_6   month_7   month_8   month_9  month_10  month_11  month_12  \
# 97066  -0.301439 -0.306619 -0.308504 -0.302913  3.196261 -0.305695 -0.300091
# 60085  -0.301439 -0.306619 -0.308504 -0.302913 -0.312866 -0.305695 -0.300091
# 4849    3.317421 -0.306619 -0.308504 -0.302913 -0.312866 -0.305695 -0.300091
# 52868  -0.301439 -0.306619 -0.308504 -0.302913 -0.312866 -0.305695 -0.300091
# 10072  -0.301439 -0.306619 -0.308504 -0.302913 -0.312866  3.271235 -0.300091
# ...          ...       ...       ...       ...       ...       ...       ...
# 1129   -0.301439 -0.306619 -0.308504 -0.302913 -0.312866 -0.305695 -0.300091
# 22544  -0.301439 -0.306619  3.241454 -0.302913 -0.312866 -0.305695 -0.300091
# 37772  -0.301439  3.261380 -0.308504 -0.302913 -0.312866 -0.305695 -0.300091
# 113539 -0.301439 -0.306619 -0.308504 -0.302913 -0.312866 -0.305695  3.332319
# 63903  -0.301439 -0.306619 -0.308504 -0.302913 -0.312866 -0.305695 -0.300091
#
#         PREV_STAT_LATE  PREV_STAT_ONTIME
# 97066        -0.654071         -0.562754
# 60085        -0.654071         -0.562754
# 4849          1.528886         -0.562754
# 52868        -0.654071          1.776974
# 10072        -0.654071          1.776974
# ...                ...               ...
# 1129         -0.654071         -0.562754
# 22544        -0.654071         -0.562754
# 37772        -0.654071          1.776974
# 113539       -0.654071         -0.562754
# 63903        -0.654071          1.776974
#
# [90940 rows x 72 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

def logistic_regression_classification(trainX, trainY, testX, testY, penalty='l2', C=1.0, max_iter=1000, solver='lbfgs'):
    """
    Perform classification using Regularized Logistic Regression for three-class prediction.
    
    Parameters:
        trainX (DataFrame or array-like): Features for training.
        trainY (Series or array-like): Target variable for training.
        testX (DataFrame or array-like): Features for testing.
        testY (Series or array-like): Target variable for testing.
        penalty (str, optional): Regularization type ('l1' for Lasso, 'l2' for Ridge). Default is 'l2'.
        C (float, optional): Inverse of regularization strength; smaller values specify stronger regularization. Default is 1.0.
        max_iter (int, optional): Maximum number of iterations for optimization algorithm. Default is 1000.
        solver (str, optional): Optimization algorithm to use ('lbfgs', 'sag', 'saga', etc.). Default is 'lbfgs'.
        
    Returns:
        dict: Dictionary containing accuracy score and classification report.
    """
    # Get unique target names
    target_names = trainY.unique() if isinstance(trainY, pd.Series) else testY.unique()
    
    # Initialize and train the Logistic Regression model
    model = LogisticRegression(penalty=penalty, C=C, max_iter=max_iter, solver=solver, verbose=1 if max_iter > 300 else 0)
    model.fit(trainX, trainY)
    
    # Predict on the testing set
    testY_pred = model.predict(testX)
    
    # Calculate accuracy score
    accuracy = accuracy_score(testY, testY_pred)
    
    # Generate classification report
    report = classification_report(testY, testY_pred, target_names=target_names, output_dict=True)
    
    results = {
        'accuracy': accuracy,
        'classification_report': report
    }
    
    return results

# %%
report = logistic_regression_classification(enc_trainX, trainY, enc_testX, testY, max_iter=1500, solver='saga')
print(report)
# Out:
# Epoch 1, change: 1.00000000
# Epoch 2, change: 0.25144802
# Epoch 3, change: 0.19113114
# Epoch 4, change: 0.15780325
# Epoch 5, change: 0.14343723
# Epoch 6, change: 0.13748756
# Epoch 7, change: 0.13117865
# Epoch 8, change: 0.11334531
# Epoch 9, change: 0.09931395
# Epoch 10, change: 0.08810882
# Epoch 11, change: 0.07926263
# Epoch 12, change: 0.07168346
# Epoch 13, change: 0.06545179
# Epoch 14, change: 0.06014111
# Epoch 15, change: 0.05557221
# Epoch 16, change: 0.05149549
# Epoch 17, change: 0.04797028
# Epoch 18, change: 0.04492433
# Epoch 19, change: 0.04219557
# Epoch 20, change: 0.03971930
# Epoch 21, change: 0.03745472
# Epoch 22, change: 0.03550737
# Epoch 23, change: 0.03364748
# Epoch 24, change: 0.03197090
# Epoch 25, change: 0.03050380
# Epoch 26, change: 0.02904795
# Epoch 27, change: 0.02784410
# Epoch 28, change: 0.02661052
# Epoch 29, change: 0.02551979
# Epoch 30, change: 0.02449783
# Epoch 31, change: 0.02355395
# Epoch 32, change: 0.02267661
# Epoch 33, change: 0.02183294
# Epoch 34, change: 0.02105511
# Epoch 35, change: 0.02033339
# Epoch 36, change: 0.01966383
# Epoch 37, change: 0.01899393
# Epoch 38, change: 0.01840455
# Epoch 39, change: 0.01783680
# Epoch 40, change: 0.01729141
# Epoch 41, change: 0.01679387
# Epoch 42, change: 0.01628194
# Epoch 43, change: 0.01583468
# Epoch 44, change: 0.01538189
# Epoch 45, change: 0.01496780
# Epoch 46, change: 0.01456421
# Epoch 47, change: 0.01418724
# Epoch 48, change: 0.01382955
# Epoch 49, change: 0.01347840
# Epoch 50, change: 0.01314944
# Epoch 51, change: 0.01281989
# Epoch 52, change: 0.01252286
# Epoch 53, change: 0.01223681
# Epoch 54, change: 0.01194565
# Epoch 55, change: 0.01168045
# Epoch 56, change: 0.01142574
# Epoch 57, change: 0.01116930
# Epoch 58, change: 0.01094050
# Epoch 59, change: 0.01070653
# Epoch 60, change: 0.01048326
# Epoch 61, change: 0.01026469
# Epoch 62, change: 0.01005574
# Epoch 63, change: 0.00985308
# Epoch 64, change: 0.00966512
# Epoch 65, change: 0.00948587
# Epoch 66, change: 0.00929704
# Epoch 67, change: 0.00912254
# Epoch 68, change: 0.00895331
# Epoch 69, change: 0.00879252
# Epoch 70, change: 0.00862795
# Epoch 71, change: 0.00847277
# Epoch 72, change: 0.00833044
# Epoch 73, change: 0.00818471
# Epoch 74, change: 0.00803807
# Epoch 75, change: 0.00790871
# Epoch 76, change: 0.00776392
# Epoch 77, change: 0.00764256
# Epoch 78, change: 0.00751462
# Epoch 79, change: 0.00739559
# Epoch 80, change: 0.00727220
# Epoch 81, change: 0.00716067
# Epoch 82, change: 0.00705064
# Epoch 83, change: 0.00693602
# Epoch 84, change: 0.00682904
# Epoch 85, change: 0.00672579
# Epoch 86, change: 0.00662289
# Epoch 87, change: 0.00652061
# Epoch 88, change: 0.00642941
# Epoch 89, change: 0.00633266
# Epoch 90, change: 0.00624501
# Epoch 91, change: 0.00614637
# Epoch 92, change: 0.00605921
# Epoch 93, change: 0.00597306
# Epoch 94, change: 0.00589255
# Epoch 95, change: 0.00580782
# Epoch 96, change: 0.00572326
# Epoch 97, change: 0.00565261
# Epoch 98, change: 0.00557332
# Epoch 99, change: 0.00549558
# Epoch 100, change: 0.00542289
# Epoch 101, change: 0.00535122
# Epoch 102, change: 0.00528315
# Epoch 103, change: 0.00521390
# Epoch 104, change: 0.00513816
# Epoch 105, change: 0.00507545
# Epoch 106, change: 0.00501072
# Epoch 107, change: 0.00495004
# Epoch 108, change: 0.00488417
# Epoch 109, change: 0.00482197
# Epoch 110, change: 0.00476747
# Epoch 111, change: 0.00470155
# Epoch 112, change: 0.00464917
# Epoch 113, change: 0.00458477
# Epoch 114, change: 0.00453537
# Epoch 115, change: 0.00447850
# Epoch 116, change: 0.00442243
# Epoch 117, change: 0.00437161
# Epoch 118, change: 0.00431809
# Epoch 119, change: 0.00426832
# Epoch 120, change: 0.00421948
# Epoch 121, change: 0.00417064
# Epoch 122, change: 0.00411853
# Epoch 123, change: 0.00407454
# Epoch 124, change: 0.00402366
# Epoch 125, change: 0.00398138
# Epoch 126, change: 0.00393204
# Epoch 127, change: 0.00388962
# Epoch 128, change: 0.00384569
# Epoch 129, change: 0.00380416
# Epoch 130, change: 0.00376185
# Epoch 131, change: 0.00371865
# Epoch 132, change: 0.00367736
# Epoch 133, change: 0.00363751
# Epoch 134, change: 0.00359808
# Epoch 135, change: 0.00355688
# Epoch 136, change: 0.00351842
# Epoch 137, change: 0.00348296
# Epoch 138, change: 0.00344485
# Epoch 139, change: 0.00340669
# Epoch 140, change: 0.00337020
# Epoch 141, change: 0.00333636
# Epoch 142, change: 0.00330033
# Epoch 143, change: 0.00326563
# Epoch 144, change: 0.00323175
# Epoch 145, change: 0.00319815
# Epoch 146, change: 0.00316445
# Epoch 147, change: 0.00313279
# Epoch 148, change: 0.00309991
# Epoch 149, change: 0.00306902
# Epoch 150, change: 0.00303686
# Epoch 151, change: 0.00300606
# Epoch 152, change: 0.00297490
# Epoch 153, change: 0.00294717
# Epoch 154, change: 0.00291362
# Epoch 155, change: 0.00288619
# Epoch 156, change: 0.00285940
# Epoch 157, change: 0.00282867
# Epoch 158, change: 0.00280018
# Epoch 159, change: 0.00277413
# Epoch 160, change: 0.00274673
# Epoch 161, change: 0.00271781
# Epoch 162, change: 0.00269142
# Epoch 163, change: 0.00266680
# Epoch 164, change: 0.00264114
# Epoch 165, change: 0.00261456
# Epoch 166, change: 0.00258814
# Epoch 167, change: 0.00256492
# Epoch 168, change: 0.00254085
# Epoch 169, change: 0.00251566
# Epoch 170, change: 0.00249149
# Epoch 171, change: 0.00246906
# Epoch 172, change: 0.00244625
# Epoch 173, change: 0.00242208
# Epoch 174, change: 0.00239685
# Epoch 175, change: 0.00237562
# Epoch 176, change: 0.00235495
# Epoch 177, change: 0.00233312
# Epoch 178, change: 0.00231037
# Epoch 179, change: 0.00228998
# Epoch 180, change: 0.00226781
# Epoch 181, change: 0.00224700
# Epoch 182, change: 0.00222662
# Epoch 183, change: 0.00220524
# Epoch 184, change: 0.00218488
# Epoch 185, change: 0.00216711
# Epoch 186, change: 0.00214656
# Epoch 187, change: 0.00212550
# Epoch 188, change: 0.00210778
# Epoch 189, change: 0.00208739
# Epoch 190, change: 0.00207039
# Epoch 191, change: 0.00205145
# Epoch 192, change: 0.00203315
# Epoch 193, change: 0.00201446
# Epoch 194, change: 0.00199485
# Epoch 195, change: 0.00197754
# Epoch 196, change: 0.00196049
# Epoch 197, change: 0.00194363
# Epoch 198, change: 0.00192732
# Epoch 199, change: 0.00190998
# Epoch 200, change: 0.00189098
# Epoch 201, change: 0.00187623
# Epoch 202, change: 0.00185807
# Epoch 203, change: 0.00184389
# Epoch 204, change: 0.00182817
# Epoch 205, change: 0.00180978
# Epoch 206, change: 0.00179634
# Epoch 207, change: 0.00177900
# Epoch 208, change: 0.00176516
# Epoch 209, change: 0.00174947
# Epoch 210, change: 0.00173462
# Epoch 211, change: 0.00171924
# Epoch 212, change: 0.00170481
# Epoch 213, change: 0.00169143
# Epoch 214, change: 0.00167525
# Epoch 215, change: 0.00166141
# Epoch 216, change: 0.00164674
# Epoch 217, change: 0.00163375
# Epoch 218, change: 0.00161932
# Epoch 219, change: 0.00160625
# Epoch 220, change: 0.00159143
# Epoch 221, change: 0.00157870
# Epoch 222, change: 0.00156500
# Epoch 223, change: 0.00155257
# Epoch 224, change: 0.00153812
# Epoch 225, change: 0.00152678
# Epoch 226, change: 0.00151375
# Epoch 227, change: 0.00149995
# Epoch 228, change: 0.00148866
# Epoch 229, change: 0.00147645
# Epoch 230, change: 0.00146436
# Epoch 231, change: 0.00145290
# Epoch 232, change: 0.00143955
# Epoch 233, change: 0.00142797
# Epoch 234, change: 0.00141638
# Epoch 235, change: 0.00140527
# Epoch 236, change: 0.00139448
# Epoch 237, change: 0.00138127
# Epoch 238, change: 0.00136998
# Epoch 239, change: 0.00136028
# Epoch 240, change: 0.00134803
# Epoch 241, change: 0.00133694
# Epoch 242, change: 0.00132667
# Epoch 243, change: 0.00131471
# Epoch 244, change: 0.00130581
# Epoch 245, change: 0.00129445
# Epoch 246, change: 0.00128415
# Epoch 247, change: 0.00127356
# Epoch 248, change: 0.00126353
# Epoch 249, change: 0.00125357
# Epoch 250, change: 0.00124302
# Epoch 251, change: 0.00123353
# Epoch 252, change: 0.00122383
# Epoch 253, change: 0.00121297
# Epoch 254, change: 0.00120467
# Epoch 255, change: 0.00119446
# Epoch 256, change: 0.00118393
# Epoch 257, change: 0.00117546
# Epoch 258, change: 0.00116616
# Epoch 259, change: 0.00115753
# Epoch 260, change: 0.00114823
# Epoch 261, change: 0.00113890
# Epoch 262, change: 0.00112897
# Epoch 263, change: 0.00112118
# Epoch 264, change: 0.00111177
# Epoch 265, change: 0.00110341
# Epoch 266, change: 0.00109489
# Epoch 267, change: 0.00108673
# Epoch 268, change: 0.00107697
# Epoch 269, change: 0.00106935
# Epoch 270, change: 0.00106067
# Epoch 271, change: 0.00105354
# Epoch 272, change: 0.00104398
# Epoch 273, change: 0.00103621
# Epoch 274, change: 0.00102805
# Epoch 275, change: 0.00102024
# Epoch 276, change: 0.00101285
# Epoch 277, change: 0.00100435
# Epoch 278, change: 0.00099650
# Epoch 279, change: 0.00098926
# Epoch 280, change: 0.00098208
# Epoch 281, change: 0.00097344
# Epoch 282, change: 0.00096678
# Epoch 283, change: 0.00095860
# Epoch 284, change: 0.00095199
# Epoch 285, change: 0.00094462
# Epoch 286, change: 0.00093756
# Epoch 287, change: 0.00093007
# Epoch 288, change: 0.00092246
# Epoch 289, change: 0.00091526
# Epoch 290, change: 0.00090950
# Epoch 291, change: 0.00090188
# Epoch 292, change: 0.00089478
# Epoch 293, change: 0.00088824
# Epoch 294, change: 0.00088220
# Epoch 295, change: 0.00087518
# Epoch 296, change: 0.00086784
# Epoch 297, change: 0.00086156
# Epoch 298, change: 0.00085540
# Epoch 299, change: 0.00084855
# Epoch 300, change: 0.00084273
# Epoch 301, change: 0.00083635
# Epoch 302, change: 0.00082983
# Epoch 303, change: 0.00082358
# Epoch 304, change: 0.00081686
# Epoch 305, change: 0.00081109
# Epoch 306, change: 0.00080542
# Epoch 307, change: 0.00079887
# Epoch 308, change: 0.00079361
# Epoch 309, change: 0.00078709
# Epoch 310, change: 0.00078185
# Epoch 311, change: 0.00077537
# Epoch 312, change: 0.00076945
# Epoch 313, change: 0.00076374
# Epoch 314, change: 0.00075857
# Epoch 315, change: 0.00075285
# Epoch 316, change: 0.00074726
# Epoch 317, change: 0.00074227
# Epoch 318, change: 0.00073576
# Epoch 319, change: 0.00073072
# Epoch 320, change: 0.00072535
# Epoch 321, change: 0.00071957
# Epoch 322, change: 0.00071480
# Epoch 323, change: 0.00070906
# Epoch 324, change: 0.00070415
# Epoch 325, change: 0.00069933
# Epoch 326, change: 0.00069347
# Epoch 327, change: 0.00068933
# Epoch 328, change: 0.00068342
# Epoch 329, change: 0.00067818
# Epoch 330, change: 0.00067316
# Epoch 331, change: 0.00066904
# Epoch 332, change: 0.00066368
# Epoch 333, change: 0.00065871
# Epoch 334, change: 0.00065447
# Epoch 335, change: 0.00064900
# Epoch 336, change: 0.00064515
# Epoch 337, change: 0.00064008
# Epoch 338, change: 0.00063500
# Epoch 339, change: 0.00063092
# Epoch 340, change: 0.00062612
# Epoch 341, change: 0.00062167
# Epoch 342, change: 0.00061684
# Epoch 343, change: 0.00061263
# Epoch 344, change: 0.00060822
# Epoch 345, change: 0.00060387
# Epoch 346, change: 0.00059925
# Epoch 347, change: 0.00059474
# Epoch 348, change: 0.00059089
# Epoch 349, change: 0.00058622
# Epoch 350, change: 0.00058247
# Epoch 351, change: 0.00057826
# Epoch 352, change: 0.00057419
# Epoch 353, change: 0.00056984
# Epoch 354, change: 0.00056526
# Epoch 355, change: 0.00056188
# Epoch 356, change: 0.00055731
# Epoch 357, change: 0.00055385
# Epoch 358, change: 0.00054942
# Epoch 359, change: 0.00054599
# Epoch 360, change: 0.00054190
# Epoch 361, change: 0.00053760
# Epoch 362, change: 0.00053409
# Epoch 363, change: 0.00053040
# Epoch 364, change: 0.00052607
# Epoch 365, change: 0.00052288
# Epoch 366, change: 0.00051909
# Epoch 367, change: 0.00051569
# Epoch 368, change: 0.00051140
# Epoch 369, change: 0.00050788
# Epoch 370, change: 0.00050457
# Epoch 371, change: 0.00050071
# Epoch 372, change: 0.00049730
# Epoch 373, change: 0.00049342
# Epoch 374, change: 0.00049028
# Epoch 375, change: 0.00048673
# Epoch 376, change: 0.00048316
# Epoch 377, change: 0.00047988
# Epoch 378, change: 0.00047648
# Epoch 379, change: 0.00047298
# Epoch 380, change: 0.00046939
# Epoch 381, change: 0.00046644
# Epoch 382, change: 0.00046281
# Epoch 383, change: 0.00045982
# Epoch 384, change: 0.00045670
# Epoch 385, change: 0.00045341
# Epoch 386, change: 0.00045008
# Epoch 387, change: 0.00044718
# Epoch 388, change: 0.00044394
# Epoch 389, change: 0.00044087
# Epoch 390, change: 0.00043764
# Epoch 391, change: 0.00043464
# Epoch 392, change: 0.00043148
# Epoch 393, change: 0.00042823
# Epoch 394, change: 0.00042581
# Epoch 395, change: 0.00042230
# Epoch 396, change: 0.00041972
# Epoch 397, change: 0.00041660
# Epoch 398, change: 0.00041376
# Epoch 399, change: 0.00041081
# Epoch 400, change: 0.00040784
# Epoch 401, change: 0.00040534
# Epoch 402, change: 0.00040207
# Epoch 403, change: 0.00039919
# Epoch 404, change: 0.00039665
# Epoch 405, change: 0.00039385
# Epoch 406, change: 0.00039158
# Epoch 407, change: 0.00038819
# Epoch 408, change: 0.00038583
# Epoch 409, change: 0.00038313
# Epoch 410, change: 0.00038034
# Epoch 411, change: 0.00037793
# Epoch 412, change: 0.00037496
# Epoch 413, change: 0.00037253
# Epoch 414, change: 0.00037002
# Epoch 415, change: 0.00036745
# Epoch 416, change: 0.00036481
# Epoch 417, change: 0.00036222
# Epoch 418, change: 0.00035975
# Epoch 419, change: 0.00035743
# Epoch 420, change: 0.00035485
# Epoch 421, change: 0.00035253
# Epoch 422, change: 0.00034988
# Epoch 423, change: 0.00034765
# Epoch 424, change: 0.00034489
# Epoch 425, change: 0.00034284
# Epoch 426, change: 0.00034062
# Epoch 427, change: 0.00033800
# Epoch 428, change: 0.00033600
# Epoch 429, change: 0.00033325
# Epoch 430, change: 0.00033109
# Epoch 431, change: 0.00032894
# Epoch 432, change: 0.00032651
# Epoch 433, change: 0.00032443
# Epoch 434, change: 0.00032198
# Epoch 435, change: 0.00031962
# Epoch 436, change: 0.00031770
# Epoch 437, change: 0.00031540
# Epoch 438, change: 0.00031349
# Epoch 439, change: 0.00031126
# Epoch 440, change: 0.00030926
# Epoch 441, change: 0.00030690
# Epoch 442, change: 0.00030485
# Epoch 443, change: 0.00030264
# Epoch 444, change: 0.00030070
# Epoch 445, change: 0.00029860
# Epoch 446, change: 0.00029682
# Epoch 447, change: 0.00029449
# Epoch 448, change: 0.00029260
# Epoch 449, change: 0.00029069
# Epoch 450, change: 0.00028857
# Epoch 451, change: 0.00028674
# Epoch 452, change: 0.00028461
# Epoch 453, change: 0.00028278
# Epoch 454, change: 0.00028097
# Epoch 455, change: 0.00027872
# Epoch 456, change: 0.00027701
# Epoch 457, change: 0.00027507
# Epoch 458, change: 0.00027335
# Epoch 459, change: 0.00027139
# Epoch 460, change: 0.00026948
# Epoch 461, change: 0.00026780
# Epoch 462, change: 0.00026591
# Epoch 463, change: 0.00026427
# Epoch 464, change: 0.00026217
# Epoch 465, change: 0.00026049
# Epoch 466, change: 0.00025871
# Epoch 467, change: 0.00025687
# Epoch 468, change: 0.00025531
# Epoch 469, change: 0.00025349
# Epoch 470, change: 0.00025200
# Epoch 471, change: 0.00025027
# Epoch 472, change: 0.00024847
# Epoch 473, change: 0.00024669
# Epoch 474, change: 0.00024505
# Epoch 475, change: 0.00024350
# Epoch 476, change: 0.00024180
# Epoch 477, change: 0.00024005
# Epoch 478, change: 0.00023864
# Epoch 479, change: 0.00023696
# Epoch 480, change: 0.00023502
# Epoch 481, change: 0.00023387
# Epoch 482, change: 0.00023220
# Epoch 483, change: 0.00023042
# Epoch 484, change: 0.00022898
# Epoch 485, change: 0.00022749
# Epoch 486, change: 0.00022600
# Epoch 487, change: 0.00022447
# Epoch 488, change: 0.00022302
# Epoch 489, change: 0.00022145
# Epoch 490, change: 0.00022001
# Epoch 491, change: 0.00021859
# Epoch 492, change: 0.00021702
# Epoch 493, change: 0.00021553
# Epoch 494, change: 0.00021406
# Epoch 495, change: 0.00021277
# Epoch 496, change: 0.00021123
# Epoch 497, change: 0.00020964
# Epoch 498, change: 0.00020855
# Epoch 499, change: 0.00020699
# Epoch 500, change: 0.00020566
# Epoch 501, change: 0.00020431
# Epoch 502, change: 0.00020275
# Epoch 503, change: 0.00020160
# Epoch 504, change: 0.00020021
# Epoch 505, change: 0.00019890
# Epoch 506, change: 0.00019749
# Epoch 507, change: 0.00019619
# Epoch 508, change: 0.00019500
# Epoch 509, change: 0.00019359
# Epoch 510, change: 0.00019229
# Epoch 511, change: 0.00019103
# Epoch 512, change: 0.00018974
# Epoch 513, change: 0.00018847
# Epoch 514, change: 0.00018723
# Epoch 515, change: 0.00018596
# Epoch 516, change: 0.00018472
# Epoch 517, change: 0.00018353
# Epoch 518, change: 0.00018244
# Epoch 519, change: 0.00018105
# Epoch 520, change: 0.00017991
# Epoch 521, change: 0.00017876
# Epoch 522, change: 0.00017756
# Epoch 523, change: 0.00017610
# Epoch 524, change: 0.00017515
# Epoch 525, change: 0.00017393
# Epoch 526, change: 0.00017284
# Epoch 527, change: 0.00017178
# Epoch 528, change: 0.00017049
# Epoch 529, change: 0.00016949
# Epoch 530, change: 0.00016824
# Epoch 531, change: 0.00016714
# Epoch 532, change: 0.00016606
# Epoch 533, change: 0.00016500
# Epoch 534, change: 0.00016375
# Epoch 535, change: 0.00016278
# Epoch 536, change: 0.00016166
# Epoch 537, change: 0.00016065
# Epoch 538, change: 0.00015960
# Epoch 539, change: 0.00015847
# Epoch 540, change: 0.00015750
# Epoch 541, change: 0.00015638
# Epoch 542, change: 0.00015535
# Epoch 543, change: 0.00015436
# Epoch 544, change: 0.00015333
# Epoch 545, change: 0.00015232
# Epoch 546, change: 0.00015135
# Epoch 547, change: 0.00015033
# Epoch 548, change: 0.00014921
# Epoch 549, change: 0.00014841
# Epoch 550, change: 0.0convergence after 610 epochs took 74 seconds
# {'accuracy': 0.49360017594018035, 'classification_report': {'ONTIME': {'precision': 0.5163681651049697, 'recall': 0.8332854818642932, 'f1-score': 0.6376185419794222, 'support': 10449.0}, 'EARLY': {'precision': 0.43142500445871235, 'recall': 0.3546400820993989, 'f1-score': 0.3892822658513035, 'support': 6821.0}, 'LATE': {'precision': 0.3609022556390977, 'recall': 0.01756633119853614, 'f1-score': 0.03350200663060548, 'support': 5465.0}, 'accuracy': 0.49360017594018035, 'macro avg': {'precision': 0.4362318084009266, 'recall': 0.40183063172074274, 'f1-score': 0.35346760482044376, 'support': 22735.0}, 'weighted avg': {'precision': 0.4535127222195899, 'recall': 0.49360017594018035, 'f1-score': 0.4178957091159438, 'support': 22735.0}}}

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

def decision_tree_classification(trainX, trainY, testX, testY, criterion='gini', max_depth=None):
    """
    Perform classification using Decision Trees for three-class prediction.
    
    Parameters:
        trainX (DataFrame or array-like): Features for training.
        trainY (Series or array-like): Target variable for training.
        testX (DataFrame or array-like): Features for testing.
        testY (Series or array-like): Target variable for testing.
        criterion (str, optional): Criterion used to measure the quality of a split ('gini' or 'entropy'). Default is 'gini'.
        max_depth (int, optional): Maximum depth of the tree. If None, the tree is fully grown. Default is None.
        
    Returns:
        dict: Dictionary containing accuracy score and classification report.
    """
    # Get unique target names
    target_names = trainY.unique() if isinstance(trainY, pd.Series) else testY.unique()
    
    # Initialize and train the Decision Tree model
    model = DecisionTreeClassifier(criterion=criterion, max_depth=max_depth)
    model.fit(trainX, trainY)
    
    # Predict on the testing set
    testY_pred = model.predict(testX)
    
    # Calculate accuracy score
    accuracy = accuracy_score(testY, testY_pred)
    
    # Generate classification report
    report = classification_report(testY, testY_pred, target_names=target_names, output_dict=True)
    
    results = {
        'accuracy': accuracy,
        'classification_report': report
    }
    
    return results

# %%
decision_tree_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# {'accuracy': 0.41706619749285245,
#  'classification_report': {'ONTIME': {'precision': 0.5287541449549976,
#    'recall': 0.534118097425591,
#    'f1-score': 0.5314225861740621,
#    'support': 10449.0},
#   'EARLY': {'precision': 0.3604974396488661,
#    'recall': 0.36123735522650635,
#    'f1-score': 0.36086701816051553,
#    'support': 6821.0},
#   'LATE': {'precision': 0.2688493919550982,
#    'recall': 0.2629460201280878,
#    'f1-score': 0.2658649398704903,
#    'support': 5465.0},
#   'accuracy': 0.41706619749285245,
#   'macro avg': {'precision': 0.38603365885298735,
#    'recall': 0.38610049092672843,
#    'f1-score': 0.3860515147350226,
#    'support': 22735.0},
#   'weighted avg': {'precision': 0.41579797772220356,
#    'recall': 0.41706619749285245,
#    'f1-score': 0.4164178768505776,
#    'support': 22735.0}}}

# %%
from sklearn.metrics import accuracy_score, classification_report

from sklearn.preprocessing import LabelEncoder

def fit_and_evaluate(model, trainX, trainY, testX, testY):
    # Convert string labels to integers
    label_encoder = LabelEncoder()
    trainY_encoded = label_encoder.fit_transform(trainY)
    testY_encoded = label_encoder.transform(testY)
    
    model.fit(trainX, trainY_encoded)
    testY_pred = model.predict(testX)
    accuracy = accuracy_score(testY_encoded, testY_pred)
    report = classification_report(testY_encoded, testY_pred, output_dict=True)
    results = {'accuracy': accuracy, 'classification_report': report}
    return results

# Update other classification functions similarly...


# Random Forest
from sklearn.ensemble import RandomForestClassifier

def random_forest_classification(trainX, trainY, testX, testY, n_estimators=100, criterion='gini', max_depth=None):
    model = RandomForestClassifier(n_estimators=n_estimators, criterion=criterion, max_depth=max_depth)
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# Support Vector Machines (SVM)
from sklearn.svm import SVC

def svm_classification(trainX, trainY, testX, testY, kernel='rbf', C=1.0):
    model = SVC(kernel=kernel, C=C)
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# K-Nearest Neighbors (KNN)
from sklearn.neighbors import KNeighborsClassifier

def knn_classification(trainX, trainY, testX, testY, n_neighbors=5):
    model = KNeighborsClassifier(n_neighbors=n_neighbors)
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# Gradient Boosting Machines (GBM)
from sklearn.ensemble import GradientBoostingClassifier

def gbm_classification(trainX, trainY, testX, testY, n_estimators=100, learning_rate=0.1, max_depth=3):
    model = GradientBoostingClassifier(n_estimators=n_estimators, learning_rate=learning_rate, max_depth=max_depth)
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# Naive Bayes
from sklearn.naive_bayes import GaussianNB

def naive_bayes_classification(trainX, trainY, testX, testY):
    model = GaussianNB()
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# AdaBoost
from sklearn.ensemble import AdaBoostClassifier

def adaboost_classification(trainX, trainY, testX, testY, n_estimators=50, learning_rate=1.0):
    model = AdaBoostClassifier(n_estimators=n_estimators, learning_rate=learning_rate)
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# XGBoost
from xgboost import XGBClassifier

def xgboost_classification(trainX, trainY, testX, testY, n_estimators=100, learning_rate=0.1, max_depth=3):
    model = XGBClassifier(n_estimators=n_estimators, learning_rate=learning_rate, max_depth=max_depth)
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# %%
random_forest_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# {'accuracy': 0.4398504508467121,
#  'classification_report': {'0': {'precision': 0.5436850057772642,
#    'recall': 0.5854148722365776,
#    'f1-score': 0.563778801843318,
#    'support': 10449.0},
#   '1': {'precision': 0.3870185016681832,
#    'recall': 0.3741386893417388,
#    'f1-score': 0.3804696235557212,
#    'support': 6821.0},
#   '2': {'precision': 0.2721881390593047,
#    'recall': 0.2435498627630375,
#    'f1-score': 0.2570738773539353,
#    'support': 5465.0},
#   'accuracy': 0.4398504508467121,
#   'macro avg': {'precision': 0.4009638821682507,
#    'recall': 0.4010344747804513,
#    'f1-score': 0.40044076758432484,
#    'support': 22735.0},
#   'weighted avg': {'precision': 0.43141966154406913,
#    'recall': 0.4398504508467121,
#    'f1-score': 0.4350568173509417,
#    'support': 22735.0}}}

# %%
knn_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# {'accuracy': 0.4620628986144711,
#  'classification_report': {'0': {'precision': 0.5161491544219573,
#    'recall': 0.7126997798832424,
#    'f1-score': 0.5987056317080034,
#    'support': 10449.0},
#   '1': {'precision': 0.40034071550255534,
#    'recall': 0.3445242633045008,
#    'f1-score': 0.37034118666771726,
#    'support': 6821.0},
#   '2': {'precision': 0.2905211325400082,
#    'recall': 0.12955169258920401,
#    'f1-score': 0.1791951404707669,
#    'support': 5465.0},
#   'accuracy': 0.4620628986144711,
#   'macro avg': {'precision': 0.402337000821507,
#    'recall': 0.3955919119256491,
#    'f1-score': 0.38274731961549585,
#    'support': 22735.0},
#   'weighted avg': {'precision': 0.42716800194981774,
#    'recall': 0.4620628986144711,
#    'f1-score': 0.42935006917308854,
#    'support': 22735.0}}}

# %%
gbm_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# {'accuracy': 0.49298438530899497,
#  'classification_report': {'0': {'precision': 0.5038180429802552,
#    'recall': 0.8840080390467987,
#    'f1-score': 0.6418371955668276,
#    'support': 10449.0},
#   '1': {'precision': 0.4556012581659811,
#    'recall': 0.27605922885207446,
#    'f1-score': 0.3438013511046193,
#    'support': 6821.0},
#   '2': {'precision': 0.3283582089552239,
#    'recall': 0.016102470265324794,
#    'f1-score': 0.030699459270887842,
#    'support': 5465.0},
#   'accuracy': 0.49298438530899497,
#   'macro avg': {'precision': 0.42925917003382014,
#    'recall': 0.39205657938806593,
#    'f1-score': 0.3387793353141116,
#    'support': 22735.0},
#   'weighted avg': {'precision': 0.4471752155263313,
#    'recall': 0.49298438530899497,
#    'f1-score': 0.40551565503751014,
#    'support': 22735.0}}}

# %%
naive_bayes_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# {'accuracy': 0.2538376951836376,
#  'classification_report': {'0': {'precision': 0.579295154185022,
#    'recall': 0.025169872715092353,
#    'f1-score': 0.048243602678161975,
#    'support': 10449.0},
#   '1': {'precision': 0.3818544366899302,
#    'recall': 0.056150124615159065,
#    'f1-score': 0.09790388548057259,
#    'support': 6821.0},
#   '2': {'precision': 0.24085910329918225,
#    'recall': 0.9377859103385179,
#    'f1-score': 0.3832778671054108,
#    'support': 5465.0},
#   'accuracy': 0.2538376951836376,
#   'macro avg': {'precision': 0.40066956472471144,
#    'recall': 0.33970196922292306,
#    'f1-score': 0.17647511842138178,
#    'support': 22735.0},
#   'weighted avg': {'precision': 0.4387059238298368,
#    'recall': 0.2538376951836376,
#    'f1-score': 0.14367773701245523,
#    'support': 22735.0}}}

# %%
adaboost_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# /home/numan947/anaconda3/envs/mldl/lib/python3.9/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# {'accuracy': 0.4873982845832417,
#  'classification_report': {'0': {'precision': 0.5043590753135722,
#    'recall': 0.8581682457651449,
#    'f1-score': 0.6353266260450616,
#    'support': 10449.0},
#   '1': {'precision': 0.42781077206635265,
#    'recall': 0.30626007916727754,
#    'f1-score': 0.35697197539302805,
#    'support': 6821.0},
#   '2': {'precision': 0.3424657534246575,
#    'recall': 0.004574565416285453,
#    'f1-score': 0.00902853015529072,
#    'support': 5465.0},
#   'accuracy': 0.4873982845832417,
#   'macro avg': {'precision': 0.42487853360152744,
#    'recall': 0.389667630116236,
#    'f1-score': 0.3337757105311268,
#    'support': 22735.0},
#   'weighted avg': {'precision': 0.4424772639842472,
#    'recall': 0.4873982845832417,
#    'f1-score': 0.4012656554651135,
#    'support': 22735.0}}}

# %%
xgboost_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# {'accuracy': 0.4913129535957774,
#  'classification_report': {'0': {'precision': 0.500080416018871,
#    'recall': 0.8927170064120968,
#    'f1-score': 0.6410555975534328,
#    'support': 10449.0},
#   '1': {'precision': 0.4587203302373581,
#    'recall': 0.2606655915554904,
#    'f1-score': 0.33242965317378703,
#    'support': 6821.0},
#   '2': {'precision': 0.3106796116504854,
#    'recall': 0.01171088746569076,
#    'f1-score': 0.0225709751366602,
#    'support': 5465.0},
#   'accuracy': 0.4913129535957774,
#   'macro avg': {'precision': 0.42316011930223824,
#    'recall': 0.388364495144426,
#    'f1-score': 0.33201874195462666,
#    'support': 22735.0},
#   'weighted avg': {'precision': 0.44214364271828044,
#    'recall': 0.4913129535957774,
#    'f1-score': 0.39979076236006456,
#    'support': 22735.0}}}

# %%
model = DecisionTreeClassifier(criterion='entropy', max_features='log2')
res = fit_and_evaluate(model, enc_trainX, trainY, enc_testX, testY)
print(res)
# Out:
# {'accuracy': 0.4229162084891137, 'classification_report': {'0': {'precision': 0.5311355311355311, 'recall': 0.5412001148435257, 'f1-score': 0.5361205915813424, 'support': 10449.0}, '1': {'precision': 0.3682807641048423, 'recall': 0.36460929482480575, 'f1-score': 0.36643583321054957, 'support': 6821.0}, '2': {'precision': 0.2761012183692596, 'recall': 0.26953339432753887, 'f1-score': 0.2727777777777778, 'support': 5465.0}, 'accuracy': 0.4229162084891137, 'macro avg': {'precision': 0.39183917120321105, 'recall': 0.3917809346652901, 'f1-score': 0.39177806752322325, 'support': 22735.0}, 'weighted avg': {'precision': 0.4209708121918758, 'recall': 0.4229162084891137, 'f1-score': 0.4219095419097498, 'support': 22735.0}}}

# %%
model = RandomForestClassifier(n_estimators=100, criterion='entropy')
res = fit_and_evaluate(model, enc_trainX, trainY, enc_testX, testY)
print(res)
# Out:
# {'accuracy': 0.439190675170442, 'classification_report': {'0': {'precision': 0.5407237826890904, 'recall': 0.5877117427505024, 'f1-score': 0.5632394753737503, 'support': 10449.0}, '1': {'precision': 0.38629379225568533, 'recall': 0.3685676587010702, 'f1-score': 0.3772225973441368, 'support': 6821.0}, '2': {'precision': 0.2731006160164271, 'recall': 0.2433668801463861, 'f1-score': 0.25737784228350263, 'support': 5465.0}, 'accuracy': 0.439190675170442, 'macro avg': {'precision': 0.40003939698706764, 'recall': 0.3998820938659862, 'f1-score': 0.39927997166713, 'support': 22735.0}, 'weighted avg': {'precision': 0.43006059506593836, 'recall': 0.439190675170442, 'f1-score': 0.4339078303384217, 'support': 22735.0}}}

# %%
model = XGBClassifier(
    colsample_bytree=0.7,enable_categorical=True,
    gamma=0.0, learning_rate=0.01, max_depth=17, 
    min_child_weight=5,n_estimators=100,
    n_jobs=20,objective='multi:softprob')
res = fit_and_evaluate(model, enc_trainX, trainY, enc_testX, testY)
print(res)
# Out:
# {'accuracy': 0.5092588519903233, 'classification_report': {'0': {'precision': 0.5277646223064172, 'recall': 0.8531916929849747, 'f1-score': 0.6521341574924107, 'support': 10449.0}, '1': {'precision': 0.4764922322158626, 'recall': 0.34173874798416654, 'f1-score': 0.39801929480064885, 'support': 6821.0}, '2': {'precision': 0.3491062039957939, 'recall': 0.060750228728270815, 'f1-score': 0.10349127182044887, 'support': 5465.0}, 'accuracy': 0.5092588519903233, 'macro avg': {'precision': 0.4511210195060246, 'recall': 0.4185602232324707, 'f1-score': 0.38454824137116944, 'support': 22735.0}, 'weighted avg': {'precision': 0.46943617590768266, 'recall': 0.5092588519903233, 'f1-score': 0.4440122815910349, 'support': 22735.0}}}

# %%
model = KNeighborsClassifier(n_neighbors=70)
res = fit_and_evaluate(model, enc_trainX, trainY, enc_testX, testY)
print(res)
# Out:
# {'accuracy': 0.48972949197272925, 'classification_report': {'0': {'precision': 0.5093936065668536, 'recall': 0.8433342903627141, 'f1-score': 0.6351448753063283, 'support': 10449.0}, '1': {'precision': 0.44491080797481636, 'recall': 0.3108048673215071, 'f1-score': 0.3659589159330226, 'support': 6821.0}, '2': {'precision': 0.30104321907600595, 'recall': 0.03696248856358646, 'f1-score': 0.06584093872229466, 'support': 5465.0}, 'accuracy': 0.48972949197272925, 'macro avg': {'precision': 0.41844921120589196, 'recall': 0.39703388208260254, 'f1-score': 0.35564824332054856, 'support': 22735.0}, 'weighted avg': {'precision': 0.4399644428618275, 'recall': 0.48972949197272925, 'f1-score': 0.4175348712457582, 'support': 22735.0}}}

# %%
model = AdaBoostClassifier(n_estimators=200, learning_rate=0.8, random_state=947)
res = fit_and_evaluate(model, enc_trainX, trainY, enc_testX, testY)
print(res)
# Out:
# /home/numan947/anaconda3/envs/mldl/lib/python3.9/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# {'accuracy': 0.4939520563008577, 'classification_report': {'0': {'precision': 0.5113453121400598, 'recall': 0.8497463872140875, 'f1-score': 0.63847840937691, 'support': 10449.0}, '1': {'precision': 0.44086021505376344, 'recall': 0.33660753555197187, 'f1-score': 0.38174411838058026, 'support': 6821.0}, '2': {'precision': 0.3374233128834356, 'recall': 0.010064043915827997, 'f1-score': 0.01954513148542999, 'support': 5465.0}, 'accuracy': 0.4939520563008577, 'macro avg': {'precision': 0.42987628002575295, 'recall': 0.3988059888939624, 'f1-score': 0.3465892197476401, 'support': 22735.0}, 'weighted avg': {'precision': 0.44839116333147927, 'recall': 0.4939520563008577, 'f1-score': 0.41267436439943467, 'support': 22735.0}}}

# %%
import numpy as np
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder

def fit_and_evaluate_voting(voting_classifier, trainX, trainY, testX, testY):
    # Convert string labels to integers
    label_encoder = LabelEncoder()
    trainY_encoded = label_encoder.fit_transform(trainY)
    testY_encoded = label_encoder.transform(testY)
    
    # Fit the VotingClassifier
    voting_classifier.fit(trainX, trainY_encoded)
    
    # Make predictions
    testY_pred = voting_classifier.predict(testX)
    
    # Calculate accuracy score
    accuracy = accuracy_score(testY_encoded, testY_pred)
    
    # Generate classification report
    report = classification_report(testY_encoded, testY_pred, target_names=label_encoder.classes_, output_dict=True)
    
    results = {
        'accuracy': accuracy,
        'classification_report': report,
        'voting_classifier': voting_classifier
    }
    
    return results

# %%
scaler = StandardScaler()
enc_trainX = pd.DataFrame(scaler.fit_transform(trainX), index=trainX.index, columns=trainX.columns)
enc_testX = pd.DataFrame(scaler.transform(testX), index=testX.index, columns=testX.columns)

# %%
from sklearn.ensemble import VotingClassifier

# Define multiple classifiers
ada = AdaBoostClassifier(n_estimators=200, learning_rate=0.8, random_state=947)
knn = KNeighborsClassifier(n_neighbors=70)
xgb = XGBClassifier(
    colsample_bytree=0.7,enable_categorical=True,
    gamma=0.0, learning_rate=0.01, max_depth=17, 
    min_child_weight=5,n_estimators=100,objective='multi:softprob')

votingCLF = VotingClassifier(estimators=[('knn', knn), ('ada', ada), ('xgb', xgb)], voting='soft', weights=[5,7,10])
fit_and_evaluate_voting(votingCLF, enc_trainX, trainY, enc_testX, testY)
# Out:
# /home/numan947/anaconda3/envs/mldl/lib/python3.9/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# {'accuracy': 0.5031009456784693,
#  'classification_report': {'EARLY': {'precision': 0.5173605113145621,
#    'recall': 0.8598908986505885,
#    'f1-score': 0.6460310612597067,
#    'support': 10449.0},
#   'LATE': {'precision': 0.46913061738765227,
#    'recall': 0.3275179592435127,
#    'f1-score': 0.3857377190710524,
#    'support': 6821.0},
#   'ONTIME': {'precision': 0.3613861386138614,
#    'recall': 0.040073193046660564,
#    'f1-score': 0.07214626914841048,
#    'support': 5465.0},
#   'accuracy': 0.5031009456784693,
#   'macro avg': {'precision': 0.4492924224386919,
#    'recall': 0.40916068364692054,
#    'f1-score': 0.36797168315972323,
#    'support': 22735.0},
#   'weighted avg': {'precision': 0.46539763234888004,
#    'recall': 0.5031009456784693,
#    'f1-score': 0.42998789979249563,
#    'support': 22735.0}},
#  'voting_classifier': VotingClassifier(estimators=[('knn', KNeighborsClassifier(n_neighbors=70)),
#                               ('ada',
#                                AdaBoostClassifier(learning_rate=0.8,
#                                                   n_estimators=200,
#                                                   random_state=947)),
#                               ('xgb',
#                                XGBClassifier(base_score=None, booster=None,
#                                              callbacks=None,
#                                              colsample_bylevel=None,
#                                              colsample_bynode=None,
#                                              colsample_bytree=0.7, device=None,
#                                              early_stopping_rounds=None,
#                                              enable_categorical=True,
#                                              ev...
#                                              interaction_constraints=None,
#                                              learning_rate=0.01, max_bin=None,
#                                              max_cat_threshold=None,
#                                              max_cat_to_onehot=None,
#                                              max_delta_step=None, max_depth=17,
#                                              max_leaves=None, min_child_weight=5,
#                                              missing=nan,
#                                              monotone_constraints=None,
#                                              multi_strategy=None,
#                                              n_estimators=100, n_jobs=None,
#                                              num_parallel_tree=None,
#                                              objective='multi:softprob', ...))],
#                   voting='soft', weights=[5, 7, 10])}

# %% [markdown]
# # 3 HOP

# %%
data = pd.read_csv("3_HOP.csv")

# %%
data.head()
# Out:
#   Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number Origin Airport  \
# 0           B6        2010-01-01             22      N608JB            JFK
# 1           B6        2010-01-01             22      N608JB            JFK
# 2           B6        2010-01-01             22      N608JB            JFK
# 3           B6        2010-01-01             44      N586JB            JFK
# 4           B6        2010-01-01             44      N586JB            JFK
#
#   Scheduled Arrival Time  Scheduled Elapsed Time (Minutes) FLIGHT_STATUS  \
# 0                  00:01                                76          LATE
# 1                  00:01                                76          LATE
# 2                  00:01                                76          LATE
# 3                  08:55                                75          LATE
# 4                  08:55                                75          LATE
#
#    month  day  season PREV_STAT
# 0      1    1  winter    ONTIME
# 1      1    1  winter    ONTIME
# 2      1    1  winter    ONTIME
# 3      1    1  winter      LATE
# 4      1    1  winter    ONTIME

# %%
data['SCHED_ARRV_TIME_CAT'] = data['Scheduled Arrival Time'].apply(convert_to_categorical)

# %%
data.head()
# Out:
#   Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number Origin Airport  \
# 0           B6        2010-01-01             22      N608JB            JFK
# 1           B6        2010-01-01             22      N608JB            JFK
# 2           B6        2010-01-01             22      N608JB            JFK
# 3           B6        2010-01-01             44      N586JB            JFK
# 4           B6        2010-01-01             44      N586JB            JFK
#
#   Scheduled Arrival Time  Scheduled Elapsed Time (Minutes) FLIGHT_STATUS  \
# 0                  00:01                                76          LATE
# 1                  00:01                                76          LATE
# 2                  00:01                                76          LATE
# 3                  08:55                                75          LATE
# 4                  08:55                                75          LATE
#
#    month  day  season PREV_STAT SCHED_ARRV_TIME_CAT
# 0      1    1  winter    ONTIME          Late Night
# 1      1    1  winter    ONTIME          Late Night
# 2      1    1  winter    ONTIME          Late Night
# 3      1    1  winter      LATE             Morning
# 4      1    1  winter    ONTIME             Morning

# %%
df = data.drop(columns=['Date (MM/DD/YYYY)', 'Flight Number','Tail Number', 'Scheduled Arrival Time'])

# %%
df.head()
# Out:
#   Carrier Code Origin Airport  Scheduled Elapsed Time (Minutes) FLIGHT_STATUS  \
# 0           B6            JFK                                76          LATE
# 1           B6            JFK                                76          LATE
# 2           B6            JFK                                76          LATE
# 3           B6            JFK                                75          LATE
# 4           B6            JFK                                75          LATE
#
#    month  day  season PREV_STAT SCHED_ARRV_TIME_CAT
# 0      1    1  winter    ONTIME          Late Night
# 1      1    1  winter    ONTIME          Late Night
# 2      1    1  winter    ONTIME          Late Night
# 3      1    1  winter      LATE             Morning
# 4      1    1  winter    ONTIME             Morning

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import OneHotEncoder

class MultiColumnOneHotEncoder(BaseEstimator, TransformerMixin):
    def __init__(self, columns=None):
        self.columns = columns
        self.encoder = None

    def fit(self, X, y=None):
        self.encoder = OneHotEncoder(sparse_output=False, drop='first')
        self.encoder.fit(X[self.columns])
        return self

    def transform(self, X):
        X_encoded = X.copy()
        encoded_data = self.encoder.transform(X[self.columns])
        encoded_df = pd.DataFrame(encoded_data, columns=self.encoder.get_feature_names_out(self.columns), index=X.index)
        
        # Drop the original columns
        X_encoded = X_encoded.drop(columns=self.columns)
        
        # Concatenate the encoded DataFrame with the original DataFrame, preserving the index
        X_encoded = pd.concat([X_encoded, encoded_df], axis=1)
        return X_encoded

    def fit_transform(self, X, y=None):
        self.fit(X)
        return self.transform(X)

# %%
df.columns
# Out:
# Index(['Carrier Code', 'Origin Airport', 'Scheduled Elapsed Time (Minutes)',
#        'FLIGHT_STATUS', 'month', 'day', 'season', 'PREV_STAT',
#        'SCHED_ARRV_TIME_CAT'],
#       dtype='object')

# %%
df['FLIGHT_STATUS'].value_counts()
# Out:
# FLIGHT_STATUS
# EARLY     156726
# LATE      102321
# ONTIME     81978
# Name: count, dtype: int64

# %%
encoder = MultiColumnOneHotEncoder(columns=['Carrier Code', 'Origin Airport','season', 'SCHED_ARRV_TIME_CAT', 'month','PREV_STAT'])

# %%
encoded_data = encoder.fit_transform(df.drop(columns=['FLIGHT_STATUS']))

# %%
trainX, testX, trainY, testY = train_test_split(
    encoded_data,
    df['FLIGHT_STATUS'], 
    test_size=0.2, 
    random_state=947,
    stratify=df['FLIGHT_STATUS']
)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()


enc_trainX = pd.DataFrame(scaler.fit_transform(trainX), index=trainX.index, columns=trainX.columns)
enc_testX = pd.DataFrame(scaler.transform(testX), index=testX.index, columns=testX.columns)

# %%
enc_trainX
# Out:
#         Scheduled Elapsed Time (Minutes)       day  Carrier Code_AA  \
# 57395                           0.051813 -1.563628        -0.239978
# 207852                         -0.823517  1.629038        -0.239978
# 103525                         -0.116520  1.058919        -0.239978
# 176924                         -1.025516  1.743062        -0.239978
# 33003                          -0.453185  1.515014        -0.239978
# ...                                  ...       ...              ...
# 180738                          0.489477 -1.221557         4.167049
# 72137                          -1.025516  1.629038        -0.239978
# 256919                         -0.789850  1.172943        -0.239978
# 215427                         -0.924517 -1.335581        -0.239978
# 338829                          3.014466 -0.537414        -0.239978
#
#         Carrier Code_B6  Carrier Code_DL  Carrier Code_EV  Carrier Code_F9  \
# 57395         -0.452409        -0.350117        -0.345110         -0.12563
# 207852        -0.452409         2.856186        -0.345110         -0.12563
# 103525        -0.452409        -0.350117        -0.345110         -0.12563
# 176924         2.210391        -0.350117        -0.345110         -0.12563
# 33003         -0.452409        -0.350117        -0.345110         -0.12563
# ...                 ...              ...              ...              ...
# 180738        -0.452409        -0.350117        -0.345110         -0.12563
# 72137         -0.452409        -0.350117         2.897628         -0.12563
# 256919        -0.452409        -0.350117        -0.345110         -0.12563
# 215427         2.210391        -0.350117        -0.345110         -0.12563
# 338829        -0.452409        -0.350117        -0.345110         -0.12563
#
#         Carrier Code_G4  Carrier Code_MQ  Carrier Code_OH  ...   month_5  \
# 57395         -0.152694         2.909811        -0.225996  ... -0.307305
# 207852        -0.152694        -0.343665        -0.225996  ... -0.307305
# 103525        -0.152694         2.909811        -0.225996  ... -0.307305
# 176924        -0.152694        -0.343665        -0.225996  ... -0.307305
# 33003         -0.152694        -0.343665        -0.225996  ... -0.307305
# ...                 ...              ...              ...  ...       ...
# 180738        -0.152694        -0.343665        -0.225996  ... -0.307305
# 72137         -0.152694        -0.343665        -0.225996  ... -0.307305
# 256919        -0.152694        -0.343665        -0.225996  ... -0.307305
# 215427        -0.152694        -0.343665        -0.225996  ... -0.307305
# 338829        -0.152694        -0.343665        -0.225996  ... -0.307305
#
#          month_6   month_7   month_8   month_9  month_10  month_11  month_12  \
# 57395  -0.299736 -0.306912 -0.309073 -0.302162 -0.312534 -0.306275 -0.300961
# 207852 -0.299736 -0.306912 -0.309073  3.309484 -0.312534 -0.306275 -0.300961
# 103525 -0.299736 -0.306912 -0.309073 -0.302162 -0.312534 -0.306275 -0.300961
# 176924 -0.299736 -0.306912 -0.309073 -0.302162 -0.312534 -0.306275  3.322687
# 33003  -0.299736 -0.306912 -0.309073 -0.302162 -0.312534 -0.306275  3.322687
# ...          ...       ...       ...       ...       ...       ...       ...
# 180738 -0.299736 -0.306912 -0.309073 -0.302162 -0.312534 -0.306275 -0.300961
# 72137  -0.299736 -0.306912 -0.309073 -0.302162  3.199656 -0.306275 -0.300961
# 256919 -0.299736 -0.306912 -0.309073 -0.302162 -0.312534  3.265037 -0.300961
# 215427 -0.299736 -0.306912 -0.309073 -0.302162 -0.312534 -0.306275  3.322687
# 338829 -0.299736 -0.306912 -0.309073 -0.302162 -0.312534 -0.306275  3.322687
#
#         PREV_STAT_LATE  PREV_STAT_ONTIME
# 57395        -0.654688         -0.562495
# 207852       -0.654688          1.777795
# 103525       -0.654688          1.777795
# 176924        1.527445         -0.562495
# 33003        -0.654688         -0.562495
# ...                ...               ...
# 180738        1.527445         -0.562495
# 72137        -0.654688          1.777795
# 256919       -0.654688         -0.562495
# 215427       -0.654688         -0.562495
# 338829       -0.654688         -0.562495
#
# [272820 rows x 72 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

def logistic_regression_classification(trainX, trainY, testX, testY, penalty='l2', C=1.0, max_iter=1000, solver='lbfgs'):
    """
    Perform classification using Regularized Logistic Regression for three-class prediction.
    
    Parameters:
        trainX (DataFrame or array-like): Features for training.
        trainY (Series or array-like): Target variable for training.
        testX (DataFrame or array-like): Features for testing.
        testY (Series or array-like): Target variable for testing.
        penalty (str, optional): Regularization type ('l1' for Lasso, 'l2' for Ridge). Default is 'l2'.
        C (float, optional): Inverse of regularization strength; smaller values specify stronger regularization. Default is 1.0.
        max_iter (int, optional): Maximum number of iterations for optimization algorithm. Default is 1000.
        solver (str, optional): Optimization algorithm to use ('lbfgs', 'sag', 'saga', etc.). Default is 'lbfgs'.
        
    Returns:
        dict: Dictionary containing accuracy score and classification report.
    """
    # Get unique target names
    target_names = trainY.unique() if isinstance(trainY, pd.Series) else testY.unique()
    
    # Initialize and train the Logistic Regression model
    model = LogisticRegression(penalty=penalty, C=C, max_iter=max_iter, solver=solver, verbose=1 if max_iter > 300 else 0)
    model.fit(trainX, trainY)
    
    # Predict on the testing set
    testY_pred = model.predict(testX)
    
    # Calculate accuracy score
    accuracy = accuracy_score(testY, testY_pred)
    
    # Generate classification report
    report = classification_report(testY, testY_pred, target_names=target_names, output_dict=True)
    
    results = {
        'accuracy': accuracy,
        'classification_report': report
    }
    
    return results

# %%
report = logistic_regression_classification(enc_trainX, trainY, enc_testX, testY, max_iter=1500, solver='saga')
print(report)
# Out:
# 0014725
# Epoch 551, change: 0.00014641
# Epoch 552, change: 0.00014537
# Epoch 553, change: 0.00014449
# Epoch 554, change: 0.00014360
# Epoch 555, change: 0.00014261
# Epoch 556, change: 0.00014154
# Epoch 557, change: 0.00014070
# Epoch 558, change: 0.00013971
# Epoch 559, change: 0.00013891
# Epoch 560, change: 0.00013792
# Epoch 561, change: 0.00013695
# Epoch 562, change: 0.00013617
# Epoch 563, change: 0.00013532
# Epoch 564, change: 0.00013424
# Epoch 565, change: 0.00013348
# Epoch 566, change: 0.00013261
# Epoch 567, change: 0.00013166
# Epoch 568, change: 0.00013088
# Epoch 569, change: 0.00012998
# Epoch 570, change: 0.00012920
# Epoch 571, change: 0.00012826
# Epoch 572, change: 0.00012749
# Epoch 573, change: 0.00012651
# Epoch 574, change: 0.00012587
# Epoch 575, change: 0.00012493
# Epoch 576, change: 0.00012410
# Epoch 577, change: 0.00012334
# Epoch 578, change: 0.00012256
# Epoch 579, change: 0.00012165
# Epoch 580, change: 0.00012090
# Epoch 581, change: 0.00012022
# Epoch 582, change: 0.00011931
# Epoch 583, change: 0.00011860
# Epoch 584, change: 0.00011782
# Epoch 585, change: 0.00011704
# Epoch 586, change: 0.00011619
# Epoch 587, change: 0.00011549
# Epoch 588, change: 0.00011474
# Epoch 589, change: 0.00011400
# Epoch 590, change: 0.00011330
# Epoch 591, change: 0.00011248
# Epoch 592, change: 0.00011178
# Epoch 593, change: 0.00011097
# Epoch 594, change: 0.00011026
# Epoch 595, change: 0.00010955
# Epoch 596, change: 0.00010895
# Epoch 597, change: 0.00010819
# Epoch 598, change: 0.00010747
# Epoch 599, change: 0.00010674
# Epoch 600, change: 0.00010606
# Epoch 601, change: 0.00010549
# Epoch 602, change: 0.00010465
# Epoch 603, change: 0.00010402
# Epoch 604, change: 0.00010339
# Epoch 605, change: 0.00010263
# Epoch 606, change: 0.00010194
# Epoch 607, change: 0.00010138
# Epoch 608, change: 0.00010066
# Epoch 609, change: 0.00010006
# Epoch 1, change: 1.00000000
# Epoch 2, change: 0.22766983
# Epoch 3, change: 0.17459485
# Epoch 4, change: 0.14409108
# Epoch 5, change: 0.13503782
# Epoch 6, change: 0.13126472
# Epoch 7, change: 0.12620727
# Epoch 8, change: 0.11110699
# Epoch 9, change: 0.09813349
# Epoch 10, change: 0.08732981
# Epoch 11, change: 0.07839715
# Epoch 12, change: 0.07111796
# Epoch 13, change: 0.06497079
# Epoch 14, change: 0.05977355
# Epoch 15, change: 0.05516719
# Epoch 16, change: 0.05117950
# Epoch 17, change: 0.04770757
# Epoch 18, change: 0.04468055
# Epoch 19, change: 0.04189805
# Epoch 20, change: 0.03948093
# Epoch 21, change: 0.03731118
# Epoch 22, change: 0.03530667
# Epoch 23, change: 0.03350344
# Epoch 24, change: 0.03183933
# Epoch 25, change: 0.03034058
# Epoch 26, change: 0.02898874
# Epoch 27, change: 0.02769356
# Epoch 28, change: 0.02651090
# Epoch 29, change: 0.02543637
# Epoch 30, change: 0.02441387
# Epoch 31, change: 0.02349245
# Epoch 32, change: 0.02259580
# Epoch 33, change: 0.02178781
# Epoch 34, change: 0.02101477
# Epoch 35, change: 0.02028868
# Epoch 36, change: 0.01961713
# Epoch 37, change: 0.01897803
# Epoch 38, change: 0.01836905
# Epoch 39, change: 0.01780738
# Epoch 40, change: 0.01726376
# Epoch 41, change: 0.01674789
# Epoch 42, change: 0.01627395
# Epoch 43, change: 0.01581239
# Epoch 44, change: 0.01536137
# Epoch 45, change: 0.01496130
# Epoch 46, change: 0.01455411
# Epoch 47, change: 0.01418861
# Epoch 48, change: 0.01381675
# Epoch 49, change: 0.01347416
# Epoch 50, change: 0.01313882
# Epoch 51, change: 0.01282701
# Epoch 52, change: 0.01252243
# Epoch 53, change: 0.01223162
# Epoch 54, change: 0.01195802
# Epoch 55, change: 0.01168363
# Epoch 56, change: 0.01142701
# Epoch 57, change: 0.01117742
# Epoch 58, change: 0.01094115
# Epoch 59, change: 0.01070921
# Epoch 60, change: 0.01049083
# Epoch 61, change: 0.01027536
# Epoch 62, change: 0.01006708
# Epoch 63, change: 0.00986761
# Epoch 64, change: 0.00967800
# Epoch 65, change: 0.00948783
# Epoch 66, change: 0.00931127
# Epoch 67, change: 0.00913363
# Epoch 68, change: 0.00896636
# Epoch 69, change: 0.00880291
# Epoch 70, change: 0.00864397
# Epoch 71, change: 0.00848365
# Epoch 72, change: 0.00834345
# Epoch 73, change: 0.00819691
# Epoch 74, change: 0.00805661
# Epoch 75, change: 0.00791955
# Epoch 76, change: 0.00778566
# Epoch 77, change: 0.00765829
# Epoch 78, change: 0.00753288
# Epoch 79, change: 0.00740859
# Epoch 80, change: 0.00728829
# Epoch 81, change: 0.00717606
# Epoch 82, change: 0.00706202
# Epoch 83, change: 0.00695300
# Epoch 84, change: 0.00684154
# Epoch 85, change: 0.00673830
# Epoch 86, change: 0.00663926
# Epoch 87, change: 0.00654156
# Epoch 88, change: 0.00644212
# Epoch 89, change: 0.00634804
# Epoch 90, change: 0.00625308
# Epoch 91, change: 0.00616639
# Epoch 92, change: 0.00607883
# Epoch 93, change: 0.00599052
# Epoch 94, change: 0.00590778
# Epoch 95, change: 0.00582538
# Epoch 96, change: 0.00574224
# Epoch 97, change: 0.00566624
# Epoch 98, change: 0.00558746
# Epoch 99, change: 0.00551404
# Epoch 100, change: 0.00544029
# Epoch 101, change: 0.00536838
# Epoch 102, change: 0.00529698
# Epoch 103, change: 0.00522666
# Epoch 104, change: 0.00515834
# Epoch 105, change: 0.00509155
# Epoch 106, change: 0.00503035
# Epoch 107, change: 0.00496177
# Epoch 108, change: 0.00490102
# Epoch 109, change: 0.00483755
# Epoch 110, change: 0.00477794
# Epoch 111, change: 0.00471960
# Epoch 112, change: 0.00466290
# Epoch 113, change: 0.00460409
# Epoch 114, change: 0.00454978
# Epoch 115, change: 0.00449265
# Epoch 116, change: 0.00444037
# Epoch 117, change: 0.00438515
# Epoch 118, change: 0.00433424
# Epoch 119, change: 0.00428194
# Epoch 120, change: 0.00423439
# Epoch 121, change: 0.00418332
# Epoch 122, change: 0.00413585
# Epoch 123, change: 0.00408714
# Epoch 124, change: 0.00403820
# Epoch 125, change: 0.00399596
# Epoch 126, change: 0.00394855
# Epoch 127, change: 0.00390460
# Epoch 128, change: 0.00386018
# Epoch 129, change: 0.00381806
# Epoch 130, change: 0.00377343
# Epoch 131, change: 0.00373305
# Epoch 132, change: 0.00369199
# Epoch 133, change: 0.00365345
# Epoch 134, change: 0.00361143
# Epoch 135, change: 0.00357255
# Epoch 136, change: 0.00353254
# Epoch 137, change: 0.00349637
# Epoch 138, change: 0.00345937
# Epoch 139, change: 0.00342201
# Epoch 140, change: 0.00338475
# Epoch 141, change: 0.00334986
# Epoch 142, change: 0.00331319
# Epoch 143, change: 0.00327881
# Epoch 144, change: 0.00324610
# Epoch 145, change: 0.00321214
# Epoch 146, change: 0.00317876
# Epoch 147, change: 0.00314482
# Epoch 148, change: 0.00311416
# Epoch 149, change: 0.00307941
# Epoch 150, change: 0.00304950
# Epoch 151, change: 0.00302002
# Epoch 152, change: 0.00298798
# Epoch 153, change: 0.00295878
# Epoch 154, change: 0.00292950
# Epoch 155, change: 0.00289958
# Epoch 156, change: 0.00287116
# Epoch 157, change: 0.00284047
# Epoch 158, change: 0.00281396
# Epoch 159, change: 0.00278664
# Epoch 160, change: 0.00275830
# Epoch 161, change: 0.00273087
# Epoch 162, change: 0.00270412
# Epoch 163, change: 0.00267977
# Epoch 164, change: 0.00265242
# Epoch 165, change: 0.00262764
# Epoch 166, change: 0.00260025
# Epoch 167, change: 0.00257716
# Epoch 168, change: 0.00255316
# Epoch 169, change: 0.00252723
# Epoch 170, change: 0.00250379
# Epoch 171, change: 0.00247997
# Epoch 172, change: 0.00245611
# Epoch 173, change: 0.00243252
# Epoch 174, change: 0.00241028
# Epoch 175, change: 0.00238750
# Epoch 176, change: 0.00236549
# Epoch 177, change: 0.00234369
# Epoch 178, change: 0.00232211
# Epoch 179, change: 0.00229966
# Epoch 180, change: 0.00227962
# Epoch 181, change: 0.00225784
# Epoch 182, change: 0.00223786
# Epoch 183, change: 0.00221632
# Epoch 184, change: 0.00219621
# Epoch 185, change: 0.00217667
# Epoch 186, change: 0.00215655
# Epoch 187, change: 0.00213800
# Epoch 188, change: 0.00211657
# Epoch 189, change: 0.00209827
# Epoch 190, change: 0.00207940
# Epoch 191, change: 0.00206173
# Epoch 192, change: 0.00204186
# Epoch 193, change: 0.00202482
# Epoch 194, change: 0.00200737
# Epoch 195, change: 0.00198879
# Epoch 196, change: 0.00197095
# Epoch 197, change: 0.00195401
# Epoch 198, change: 0.00193535
# Epoch 199, change: 0.00191908
# Epoch 200, change: 0.00190322
# Epoch 201, change: 0.00188601
# Epoch 202, change: 0.00186886
# Epoch 203, change: 0.00185291
# Epoch 204, change: 0.00183686
# Epoch 205, change: 0.00182131
# Epoch 206, change: 0.00180484
# Epoch 207, change: 0.00178940
# Epoch 208, change: 0.00177445
# Epoch 209, change: 0.00175846
# Epoch 210, change: 0.00174378
# Epoch 211, change: 0.00172924
# Epoch 212, change: 0.00171387
# Epoch 213, change: 0.00169961
# Epoch 214, change: 0.00168502
# Epoch 215, change: 0.00167028
# Epoch 216, change: 0.00165710
# Epoch 217, change: 0.00164190
# Epoch 218, change: 0.00162813
# Epoch 219, change: 0.00161526
# Epoch 220, change: 0.00160066
# Epoch 221, change: 0.00158718
# Epoch 222, change: 0.00157415
# Epoch 223, change: 0.00156135
# Epoch 224, change: 0.00154854
# Epoch 225, change: 0.00153547
# Epoch 226, change: 0.00152185
# Epoch 227, change: 0.00150983
# Epoch 228, change: 0.00149722
# Epoch 229, change: 0.00148487
# Epoch 230, change: 0.00147282
# Epoch 231, change: 0.00146019
# Epoch 232, change: 0.00144799
# Epoch 233, change: 0.00143665
# Epoch 234, change: 0.00142490
# Epoch 235, change: 0.00141332
# Epoch 236, change: 0.00140144
# Epoch 237, change: 0.00139001
# Epoch 238, change: 0.00137815
# Epoch 239, change: 0.00136774
# Epoch 240, change: 0.00135659
# Epoch 241, change: 0.00134571
# Epoch 242, change: 0.00133415
# Epoch 243, change: 0.00132374
# Epoch 244, change: 0.00131218
# Epoch 245, change: 0.00130324
# Epoch 246, change: 0.00129186
# Epoch 247, change: 0.00128119
# Epoch 248, change: 0.00127109
# Epoch 249, change: 0.00126077
# Epoch 250, change: 0.00125073
# Epoch 251, change: 0.00124105
# Epoch 252, change: 0.00123097
# Epoch 253, change: 0.00122104
# Epoch 254, change: 0.00121214
# Epoch 255, change: 0.00120174
# Epoch 256, change: 0.00119202
# Epoch 257, change: 0.00118307
# Epoch 258, change: 0.00117302
# Epoch 259, change: 0.00116514
# Epoch 260, change: 0.00115568
# Epoch 261, change: 0.00114577
# Epoch 262, change: 0.00113688
# Epoch 263, change: 0.00112823
# Epoch 264, change: 0.00111931
# Epoch 265, change: 0.00111084
# Epoch 266, change: 0.00110180
# Epoch 267, change: 0.00109333
# Epoch 268, change: 0.00108498
# Epoch 269, change: 0.00107554
# Epoch 270, change: 0.00106761
# Epoch 271, change: 0.00105957
# Epoch 272, change: 0.00105137
# Epoch 273, change: 0.00104293
# Epoch 274, change: 0.00103475
# Epoch 275, change: 0.00102723
# Epoch 276, change: 0.00101929
# Epoch 277, change: 0.00101169
# Epoch 278, change: 0.00100391
# Epoch 279, change: 0.00099505
# Epoch 280, change: 0.00098843
# Epoch 281, change: 0.00098092
# Epoch 282, change: 0.00097311
# Epoch 283, change: 0.00096537
# Epoch 284, change: 0.00095820
# Epoch 285, change: 0.00095071
# Epoch 286, change: 0.00094385
# Epoch 287, change: 0.00093609
# Epoch 288, change: 0.00092966
# Epoch 289, change: 0.00092225
# Epoch 290, change: 0.00091504
# Epoch 291, change: 0.00090834
# Epoch 292, change: 0.00090162
# Epoch 293, change: 0.00089458
# Epoch 294, change: 0.00088812
# Epoch 295, change: 0.00088086
# Epoch 296, change: 0.00087483
# Epoch 297, change: 0.00086742
# Epoch 298, change: 0.00086147
# Epoch 299, change: 0.00085497
# Epoch 300, change: 0.00084802
# Epoch 301, change: 0.00084199
# Epoch 302, change: 0.00083596
# Epoch 303, change: 0.00082957
# Epoch 304, change: 0.00082348
# Epoch 305, change: 0.00081682
# Epoch 306, change: 0.00081123
# Epoch 307, change: 0.00080498
# Epoch 308, change: 0.00079890
# Epoch 309, change: 0.00079297
# Epoch 310, change: 0.00078723
# Epoch 311, change: 0.00078139
# Epoch 312, change: 0.00077529
# Epoch 313, change: 0.00077005
# Epoch 314, change: 0.00076417
# Epoch 315, change: 0.00075803
# Epoch 316, change: 0.00075267
# Epoch 317, change: 0.00074733
# Epoch 318, change: 0.00074172
# Epoch 319, change: 0.00073636
# Epoch 320, change: 0.00073052
# Epoch 321, change: 0.00072557
# Epoch 322, change: 0.00072004
# Epoch 323, change: 0.00071505
# Epoch 324, change: 0.00070948
# Epoch 325, change: 0.00070430
# Epoch 326, change: 0.00069886
# Epoch 327, change: 0.00069423
# Epoch 328, change: 0.00068858
# Epoch 329, change: 0.00068395
# Epoch 330, change: 0.00067898
# Epoch 331, change: 0.00067428
# Epoch 332, change: 0.00066867
# Epoch 333, change: 0.00066398
# Epoch 334, change: 0.00065967
# Epoch 335, change: 0.00065452
# Epoch 336, change: 0.00064994
# Epoch 337, change: 0.00064490
# Epoch 338, change: 0.00064015
# Epoch 339, change: 0.00063576
# Epoch 340, change: 0.00063123
# Epoch 341, change: 0.00062641
# Epoch 342, change: 0.00062219
# Epoch 343, change: 0.00061742
# Epoch 344, change: 0.00061303
# Epoch 345, change: 0.00060882
# Epoch 346, change: 0.00060419
# Epoch 347, change: 0.00059991
# Epoch 348, change: 0.00059565
# Epoch 349, change: 0.00059138
# Epoch 350, change: 0.00058718
# Epoch 351, change: 0.00058259
# Epoch 352, change: 0.00057862
# Epoch 353, change: 0.00057458
# Epoch 354, change: 0.00057047
# Epoch 355, change: 0.00056620
# Epoch 356, change: 0.00056220
# Epoch 357, change: 0.00055818
# Epoch 358, change: 0.00055422
# Epoch 359, change: 0.00055030
# Epoch 360, change: 0.00054623
# Epoch 361, change: 0.00054253
# Epoch 362, change: 0.00053845
# Epoch 363, change: 0.00053481
# Epoch 364, change: 0.00053077
# Epoch 365, change: 0.00052720
# Epoch 366, change: 0.00052344
# Epoch 367, change: 0.00051958
# Epoch 368, change: 0.00051614
# Epoch 369, change: 0.00051234
# Epoch 370, change: 0.00050872
# Epoch 371, change: 0.00050518
# Epoch 372, change: 0.00050161
# Epoch 373, change: 0.00049787
# Epoch 374, change: 0.00049448
# Epoch 375, change: 0.00049092
# Epoch 376, change: 0.00048757
# Epoch 377, change: 0.00048408
# Epoch 378, change: 0.00048057
# Epoch 379, change: 0.00047737
# Epoch 380, change: 0.00047391
# Epoch 381, change: 0.00047052
# Epoch 382, change: 0.00046740
# Epoch 383, change: 0.00046382
# Epoch 384, change: 0.00046059
# Epoch 385, change: 0.00045764
# Epoch 386, change: 0.00045423
# Epoch 387, change: 0.00045114
# Epoch 388, change: 0.00044797
# Epoch 389, change: 0.00044448
# Epoch 390, change: 0.00044178
# Epoch 391, change: 0.00043856
# Epoch 392, change: 0.00043561
# Epoch 393, change: 0.00043245
# Epoch 394, change: 0.00042952
# Epoch 395, change: 0.00042648
# Epoch 396, change: 0.00042351
# Epoch 397, change: 0.00042047
# Epoch 398, change: 0.00041761
# Epoch 399, change: 0.00041461
# Epoch 400, change: 0.00041159
# Epoch 401, change: 0.00040893
# Epoch 402, change: 0.00040605
# Epoch 403, change: 0.00040332
# Epoch 404, change: 0.00040052
# Epoch 405, change: 0.00039763
# Epoch 406, change: 0.00039494
# Epoch 407, change: 0.00039199
# Epoch 408, change: 0.00038928
# Epoch 409, change: 0.00038695
# Epoch 410, change: 0.00038413
# Epoch 411, change: 0.00038127
# Epoch 412, change: 0.00037886
# Epoch 413, change: 0.00037615
# Epoch 414, change: 0.00037372
# Epoch 415, change: 0.00037088
# Epoch 416, change: 0.00036840
# Epoch 417, change: 0.00036592
# Epoch 418, change: 0.00036338
# Epoch 419, change: 0.00036084
# Epoch 420, change: 0.00035828
# Epoch 421, change: 0.00035594
# Epoch 422, change: 0.00035341
# Epoch 423, change: 0.00035111
# Epoch 424, change: 0.00034846
# Epoch 425, change: 0.00034623
# Epoch 426, change: 0.00034387
# Epoch 427, change: 0.00034124
# Epoch 428, change: 0.00033919
# Epoch 429, change: 0.00033682
# Epoch 430, change: 0.00033453
# Epoch 431, change: 0.00033232
# Epoch 432, change: 0.00033000
# Epoch 433, change: 0.00032749
# Epoch 434, change: 0.00032547
# Epoch 435, change: 0.00032318
# Epoch 436, change: 0.00032089
# Epoch 437, change: 0.00031879
# Epoch 438, change: 0.00031648
# Epoch 439, change: 0.00031456
# Epoch 440, change: 0.00031219
# Epoch 441, change: 0.00031022
# Epoch 442, change: 0.00030801
# Epoch 443, change: 0.00030596
# Epoch 444, change: 0.00030387
# Epoch 445, change: 0.00030178
# Epoch 446, change: 0.00029974
# Epoch 447, change: 0.00029760
# Epoch 448, change: 0.00029574
# Epoch 449, change: 0.00029366
# Epoch 450, change: 0.00029175
# Epoch 451, change: 0.00028961
# Epoch 452, change: 0.00028775
# Epoch 453, change: 0.00028578
# Epoch 454, change: 0.00028383
# Epoch 455, change: 0.00028198
# Epoch 456, change: 0.00027977
# Epoch 457, change: 0.00027812
# Epoch 458, change: 0.00027623
# Epoch 459, change: 0.00027429
# Epoch 460, change: 0.00027252
# Epoch 461, change: 0.00027054
# Epoch 462, change: 0.00026894
# Epoch 463, change: 0.00026701
# Epoch 464, change: 0.00026512
# Epoch 465, change: 0.00026332
# Epoch 466, change: 0.00026173
# Epoch 467, change: 0.00025989
# Epoch 468, change: 0.00025806
# Epoch 469, change: 0.00025636
# Epoch 470, change: 0.00025462
# Epoch 471, change: 0.00025289
# Epoch 472, change: 0.00025116
# Epoch 473, change: 0.00024951
# Epoch 474, change: 0.00024795
# Epoch 475, change: 0.00024611
# Epoch 476, change: 0.00024454
# Epoch 477, change: 0.00024282
# Epoch 478, change: 0.00024132
# Epoch 479, change: 0.00023967
# Epoch 480, change: 0.00023797
# Epoch 481, change: 0.00023642
# Epoch 482, change: 0.00023483
# Epoch 483, change: 0.00023327
# Epoch 484, change: 0.00023168
# Epoch 485, change: 0.00023010
# Epoch 486, change: 0.00022861
# Epoch 487, change: 0.00022697
# Epoch 488, change: 0.00022565
# Epoch 489, change: 0.00022409
# Epoch 490, change: 0.00022246
# Epoch 491, chaconvergence after 612 epochs took 251 seconds
# {'accuracy': 0.4915328788212008, 'classification_report': {'LATE': {'precision': 0.5149036461943712, 'recall': 0.8294145796777795, 'f1-score': 0.6353682975707513, 'support': 31345.0}, 'ONTIME': {'precision': 0.4280908822661552, 'recall': 0.3544761532447224, 'f1-score': 0.3878211125664947, 'support': 20464.0}, 'EARLY': {'precision': 0.3550065019505852, 'recall': 0.016650402537204196, 'f1-score': 0.03180891348674628, 'support': 16396.0}, 'accuracy': 0.4915328788212008, 'macro avg': {'precision': 0.4326670101370372, 'recall': 0.40018037848656873, 'f1-score': 0.3516661078746641, 'support': 68205.0}, 'weighted avg': {'precision': 0.45041849146893864, 'recall': 0.4915328788212008, 'f1-score': 0.4160036578028684, 'support': 68205.0}}}

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

def decision_tree_classification(trainX, trainY, testX, testY, criterion='gini', max_depth=None):
    """
    Perform classification using Decision Trees for three-class prediction.
    
    Parameters:
        trainX (DataFrame or array-like): Features for training.
        trainY (Series or array-like): Target variable for training.
        testX (DataFrame or array-like): Features for testing.
        testY (Series or array-like): Target variable for testing.
        criterion (str, optional): Criterion used to measure the quality of a split ('gini' or 'entropy'). Default is 'gini'.
        max_depth (int, optional): Maximum depth of the tree. If None, the tree is fully grown. Default is None.
        
    Returns:
        dict: Dictionary containing accuracy score and classification report.
    """
    # Get unique target names
    target_names = trainY.unique() if isinstance(trainY, pd.Series) else testY.unique()
    
    # Initialize and train the Decision Tree model
    model = DecisionTreeClassifier(criterion=criterion, max_depth=max_depth)
    model.fit(trainX, trainY)
    
    # Predict on the testing set
    testY_pred = model.predict(testX)
    
    # Calculate accuracy score
    accuracy = accuracy_score(testY, testY_pred)
    
    # Generate classification report
    report = classification_report(testY, testY_pred, target_names=target_names, output_dict=True)
    
    results = {
        'accuracy': accuracy,
        'classification_report': report
    }
    
    return results

# %%
decision_tree_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# {'accuracy': 0.7412359797668793,
#  'classification_report': {'LATE': {'precision': 0.785244772755728,
#    'recall': 0.800350933163184,
#    'f1-score': 0.7927258938587205,
#    'support': 31345.0},
#   'ONTIME': {'precision': 0.7183043178912166,
#    'recall': 0.7137412040656763,
#    'f1-score': 0.716015490955439,
#    'support': 20464.0},
#   'EARLY': {'precision': 0.6822206870564592,
#    'recall': 0.6625396438155647,
#    'f1-score': 0.6722361459203564,
#    'support': 16396.0},
#   'accuracy': 0.7412359797668793,
#   'macro avg': {'precision': 0.7285899259011347,
#    'recall': 0.7255439270148084,
#    'f1-score': 0.7269925102448386,
#    'support': 68205.0},
#   'weighted avg': {'precision': 0.7403939205092274,
#    'recall': 0.7412359797668793,
#    'f1-score': 0.7407450773172621,
#    'support': 68205.0}}}

# %%
from sklearn.metrics import accuracy_score, classification_report

from sklearn.preprocessing import LabelEncoder

def fit_and_evaluate(model, trainX, trainY, testX, testY):
    # Convert string labels to integers
    label_encoder = LabelEncoder()
    trainY_encoded = label_encoder.fit_transform(trainY)
    testY_encoded = label_encoder.transform(testY)
    
    model.fit(trainX, trainY_encoded)
    testY_pred = model.predict(testX)
    accuracy = accuracy_score(testY_encoded, testY_pred)
    report = classification_report(testY_encoded, testY_pred, output_dict=True)
    results = {'accuracy': accuracy, 'classification_report': report}
    return results

# Update other classification functions similarly...


# Random Forest
from sklearn.ensemble import RandomForestClassifier

def random_forest_classification(trainX, trainY, testX, testY, n_estimators=100, criterion='gini', max_depth=None):
    model = RandomForestClassifier(n_estimators=n_estimators, criterion=criterion, max_depth=max_depth)
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# Support Vector Machines (SVM)
from sklearn.svm import SVC

def svm_classification(trainX, trainY, testX, testY, kernel='rbf', C=1.0):
    model = SVC(kernel=kernel, C=C)
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# K-Nearest Neighbors (KNN)
from sklearn.neighbors import KNeighborsClassifier

def knn_classification(trainX, trainY, testX, testY, n_neighbors=5):
    model = KNeighborsClassifier(n_neighbors=n_neighbors)
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# Gradient Boosting Machines (GBM)
from sklearn.ensemble import GradientBoostingClassifier

def gbm_classification(trainX, trainY, testX, testY, n_estimators=100, learning_rate=0.1, max_depth=3):
    model = GradientBoostingClassifier(n_estimators=n_estimators, learning_rate=learning_rate, max_depth=max_depth)
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# Naive Bayes
from sklearn.naive_bayes import GaussianNB

def naive_bayes_classification(trainX, trainY, testX, testY):
    model = GaussianNB()
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# AdaBoost
from sklearn.ensemble import AdaBoostClassifier

def adaboost_classification(trainX, trainY, testX, testY, n_estimators=50, learning_rate=1.0):
    model = AdaBoostClassifier(n_estimators=n_estimators, learning_rate=learning_rate)
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# XGBoost
from xgboost import XGBClassifier

def xgboost_classification(trainX, trainY, testX, testY, n_estimators=100, learning_rate=0.1, max_depth=3):
    model = XGBClassifier(n_estimators=n_estimators, learning_rate=learning_rate, max_depth=max_depth)
    return fit_and_evaluate(model, trainX, trainY, testX, testY)

# %%
random_forest_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# {'accuracy': 0.6984238692177993,
#  'classification_report': {'0': {'precision': 0.754432206846779,
#    'recall': 0.7670441856755463,
#    'f1-score': 0.7606859240041763,
#    'support': 31345.0},
#   '1': {'precision': 0.6699128902809044,
#    'recall': 0.6689308053166536,
#    'f1-score': 0.6694214876033058,
#    'support': 20464.0},
#   '2': {'precision': 0.622814740284241,
#    'recall': 0.6040497682361552,
#    'f1-score': 0.6132887485293207,
#    'support': 16396.0},
#   'accuracy': 0.6984238692177993,
#   'macro avg': {'precision': 0.6823866124706415,
#    'recall': 0.6800082530761183,
#    'f1-score': 0.6811320533789343,
#    'support': 68205.0},
#   'weighted avg': {'precision': 0.69743340505859,
#    'recall': 0.6984238692177993,
#    'f1-score': 0.6978700085200747,
#    'support': 68205.0}}}

# %%
knn_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# {'accuracy': 0.5305915988563888,
#  'classification_report': {'0': {'precision': 0.5778555618469141,
#    'recall': 0.7162864890732175,
#    'f1-score': 0.6396672317269477,
#    'support': 31345.0},
#   '1': {'precision': 0.4865331311123895,
#    'recall': 0.454603205629398,
#    'f1-score': 0.470026525198939,
#    'support': 20464.0},
#   '2': {'precision': 0.43343108504398825,
#    'recall': 0.2704318126372286,
#    'f1-score': 0.33305791331780965,
#    'support': 16396.0},
#   'accuracy': 0.5305915988563888,
#   'macro avg': {'precision': 0.4992732593344306,
#    'recall': 0.48044050244661474,
#    'f1-score': 0.4809172234145655,
#    'support': 68205.0},
#   'weighted avg': {'precision': 0.515736861689857,
#    'recall': 0.5305915988563888,
#    'f1-score': 0.5150620883646517,
#    'support': 68205.0}}}

# %%
gbm_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# {'accuracy': 0.4949783740195,
#  'classification_report': {'0': {'precision': 0.5037164612037709,
#    'recall': 0.8864252671877493,
#    'f1-score': 0.6423906132593492,
#    'support': 31345.0},
#   '1': {'precision': 0.46042525669011236,
#    'recall': 0.2782935887412041,
#    'f1-score': 0.346907075198733,
#    'support': 20464.0},
#   '2': {'precision': 0.41420118343195267,
#    'recall': 0.017077335935594046,
#    'f1-score': 0.03280224929709466,
#    'support': 16396.0},
#   'accuracy': 0.4949783740195,
#   'macro avg': {'precision': 0.45944763377527864,
#    'recall': 0.39393206395484914,
#    'f1-score': 0.3406999792517256,
#    'support': 68205.0},
#   'weighted avg': {'precision': 0.4692086728669299,
#    'recall': 0.4949783740195,
#    'f1-score': 0.4071939863493342,
#    'support': 68205.0}}}

# %%
naive_bayes_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# {'accuracy': 0.31131148742760795,
#  'classification_report': {'0': {'precision': 0.5722300140252454,
#    'recall': 0.03904929015791992,
#    'f1-score': 0.07310954485724525,
#    'support': 31345.0},
#   '1': {'precision': 0.35908942024238455,
#    'recall': 0.5357212666145426,
#    'f1-score': 0.4299721535866965,
#    'support': 20464.0},
#   '2': {'precision': 0.2545587573165241,
#    'recall': 0.5517199316906563,
#    'f1-score': 0.3483786490025418,
#    'support': 16396.0},
#   'accuracy': 0.31131148742760795,
#   'macro avg': {'precision': 0.39529273052805136,
#    'recall': 0.3754968294877063,
#    'f1-score': 0.2838201158154945,
#    'support': 68205.0},
#   'weighted avg': {'precision': 0.43191409823947224,
#    'recall': 0.31131148742760795,
#    'f1-score': 0.24635415531990593,
#    'support': 68205.0}}}

# %%
adaboost_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# /home/numan947/anaconda3/envs/mldl/lib/python3.9/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# {'accuracy': 0.48596143977714246,
#  'classification_report': {'0': {'precision': 0.5021168659193912,
#    'recall': 0.8588929653852289,
#    'f1-score': 0.6337421435465267,
#    'support': 31345.0},
#   '1': {'precision': 0.42723102585487904,
#    'recall': 0.3003811571540266,
#    'f1-score': 0.3527487662114082,
#    'support': 20464.0},
#   '2': {'precision': 0.38,
#    'recall': 0.004635276896804099,
#    'f1-score': 0.0091588334538443,
#    'support': 16396.0},
#   'accuracy': 0.48596143977714246,
#   'macro avg': {'precision': 0.43644929725809006,
#    'recall': 0.3879697998120199,
#    'f1-score': 0.3318832477372597,
#    'support': 68205.0},
#   'weighted avg': {'precision': 0.4502923374435534,
#    'recall': 0.48596143977714246,
#    'f1-score': 0.3992884168979601,
#    'support': 68205.0}}}

# %%
xgboost_classification(enc_trainX, trainY, enc_testX, testY)
# Out:
# {'accuracy': 0.49316032548933364,
#  'classification_report': {'0': {'precision': 0.4995575221238938,
#    'recall': 0.9004625937151061,
#    'f1-score': 0.6426091411008026,
#    'support': 31345.0},
#   '1': {'precision': 0.4648337028824834,
#    'recall': 0.256108287724785,
#    'f1-score': 0.33025615173760986,
#    'support': 20464.0},
#   '2': {'precision': 0.3953488372093023,
#    'recall': 0.010368382532324957,
#    'f1-score': 0.020206822774277905,
#    'support': 16396.0},
#   'accuracy': 0.49316032548933364,
#   'macro avg': {'precision': 0.4532466874052265,
#    'recall': 0.38897975465740536,
#    'f1-score': 0.33102403853756346,
#    'support': 68205.0},
#   'weighted avg': {'precision': 0.4640880721595823,
#    'recall': 0.49316032548933364,
#    'f1-score': 0.3992706763898566,
#    'support': 68205.0}}}

# %%
model = DecisionTreeClassifier(criterion='entropy', max_features='log2')
res = fit_and_evaluate(model, enc_trainX, trainY, enc_testX, testY)
print(res)
# Out:
# {'accuracy': 0.6972949197272927, 'classification_report': {'0': {'precision': 0.7488874365916659, 'recall': 0.7677141489870792, 'f1-score': 0.7581839377422099, 'support': 31345.0}, '1': {'precision': 0.671620561114381, 'recall': 0.6691262705238468, 'f1-score': 0.6703710956623911, 'support': 20464.0}, '2': {'precision': 0.6249681203774547, 'recall': 0.5978287387167602, 'f1-score': 0.6110972568578553, 'support': 16396.0}, 'accuracy': 0.6972949197272927, 'macro avg': {'precision': 0.6818253726945005, 'recall': 0.678223052742562, 'f1-score': 0.6798840967541522, 'support': 68205.0}, 'weighted avg': {'precision': 0.6959152139039544, 'recall': 0.6972949197272927, 'f1-score': 0.6964782677751798, 'support': 68205.0}}}

# %%
model = RandomForestClassifier(n_estimators=100, criterion='entropy')
res = fit_and_evaluate(model, enc_trainX, trainY, enc_testX, testY)
print(res)
# Out:
# {'accuracy': 0.6997727439337292, 'classification_report': {'0': {'precision': 0.7554182479691371, 'recall': 0.7683841122986123, 'f1-score': 0.761846017587145, 'support': 31345.0}, '1': {'precision': 0.6718413320274241, 'recall': 0.6703967943706021, 'f1-score': 0.6711182858820076, 'support': 20464.0}, '2': {'precision': 0.6240724437177714, 'recall': 0.6052695779458405, 'f1-score': 0.6145272153074494, 'support': 16396.0}, 'accuracy': 0.6997727439337292, 'macro avg': {'precision': 0.6837773412381108, 'recall': 0.6813501615383516, 'f1-score': 0.682497172925534, 'support': 68205.0}, 'weighted avg': {'precision': 0.6987675066109288, 'recall': 0.6997727439337292, 'f1-score': 0.6992099735465055, 'support': 68205.0}}}

# %%
model = XGBClassifier(
    colsample_bytree=0.7,enable_categorical=True,
    gamma=0.0, learning_rate=0.01, max_depth=17, 
    min_child_weight=5,n_estimators=100,
    n_jobs=20,objective='multi:softprob')
res = fit_and_evaluate(model, enc_trainX, trainY, enc_testX, testY)
print(res)
# Out:
# {'accuracy': 0.5609266182831171, 'classification_report': {'0': {'precision': 0.5558276298095257, 'recall': 0.8834901898229383, 'f1-score': 0.6823625073920757, 'support': 31345.0}, '1': {'precision': 0.5634381099818268, 'recall': 0.4090598123534011, 'f1-score': 0.4739956399875428, 'support': 20464.0}, '2': {'precision': 0.6224113475177305, 'recall': 0.1338131251524762, 'f1-score': 0.2202700667637167, 'support': 16396.0}, 'accuracy': 0.5609266182831171, 'macro avg': {'precision': 0.5805590291030277, 'recall': 0.47545437577627186, 'f1-score': 0.45887607138111175, 'support': 68205.0}, 'weighted avg': {'precision': 0.5741173080118525, 'recall': 0.5609266182831171, 'f1-score': 0.5087610524971422, 'support': 68205.0}}}

# %%
model = KNeighborsClassifier(n_neighbors=70)
res = fit_and_evaluate(model, enc_trainX, trainY, enc_testX, testY)
print(res)
# Out:
# {'accuracy': 0.5060919287442269, 'classification_report': {'0': {'precision': 0.5307745432475985, 'recall': 0.8091242622427819, 'f1-score': 0.6410373066424022, 'support': 31345.0}, '1': {'precision': 0.4631933177092723, 'recall': 0.3766614542611415, 'f1-score': 0.4154696132596685, 'support': 20464.0}, '2': {'precision': 0.3829674689235652, 'recall': 0.08831422298121493, 'f1-score': 0.14352976160975367, 'support': 16396.0}, 'accuracy': 0.5060919287442269, 'macro avg': {'precision': 0.4589784432934787, 'recall': 0.4246999798283794, 'f1-score': 0.40001222717060814, 'support': 68205.0}, 'weighted avg': {'precision': 0.4749659223248926, 'recall': 0.5060919287442269, 'f1-score': 0.45376143264871305, 'support': 68205.0}}}

# %%
model = AdaBoostClassifier(n_estimators=200, learning_rate=0.8, random_state=947)
res = fit_and_evaluate(model, enc_trainX, trainY, enc_testX, testY)
print(res)
# Out:
# /home/numan947/anaconda3/envs/mldl/lib/python3.9/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# {'accuracy': 0.49157686386628546, 'classification_report': {'0': {'precision': 0.5096482354513008, 'recall': 0.8518743021215505, 'f1-score': 0.6377510807518689, 'support': 31345.0}, '1': {'precision': 0.43336579032781564, 'recall': 0.32623143080531664, 'f1-score': 0.37224344141180404, 'support': 20464.0}, '2': {'precision': 0.36855036855036855, 'recall': 0.009148572822639669, 'f1-score': 0.017853954650955187, 'support': 16396.0}, 'accuracy': 0.49157686386628546, 'macro avg': {'precision': 0.43718813144316165, 'recall': 0.39575143524983564, 'f1-score': 0.34261615893820946, 'support': 68205.0}, 'weighted avg': {'precision': 0.45284177576777784, 'recall': 0.49157686386628546, 'f1-score': 0.40907016863390583, 'support': 68205.0}}}

# %%
import numpy as np
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder

def fit_and_evaluate_voting(voting_classifier, trainX, trainY, testX, testY):
    # Convert string labels to integers
    label_encoder = LabelEncoder()
    trainY_encoded = label_encoder.fit_transform(trainY)
    testY_encoded = label_encoder.transform(testY)
    
    # Fit the VotingClassifier
    voting_classifier.fit(trainX, trainY_encoded)
    
    # Make predictions
    testY_pred = voting_classifier.predict(testX)
    
    # Calculate accuracy score
    accuracy = accuracy_score(testY_encoded, testY_pred)
    
    # Generate classification report
    report = classification_report(testY_encoded, testY_pred, target_names=label_encoder.classes_, output_dict=True)
    
    results = {
        'accuracy': accuracy,
        'classification_report': report,
        'voting_classifier': voting_classifier
    }
    
    return results

# %%
scaler = StandardScaler()
enc_trainX = pd.DataFrame(scaler.fit_transform(trainX), index=trainX.index, columns=trainX.columns)
enc_testX = pd.DataFrame(scaler.transform(testX), index=testX.index, columns=testX.columns)

# %%
from sklearn.ensemble import VotingClassifier

# Define multiple classifiers
ada = AdaBoostClassifier(n_estimators=200, learning_rate=0.8, random_state=947)
knn = KNeighborsClassifier(n_neighbors=70)
dt = DecisionTreeClassifier(criterion='entropy', max_features='log2')
rf = RandomForestClassifier(n_estimators=100, criterion='entropy')
xgb = XGBClassifier(
    colsample_bytree=0.7,enable_categorical=True,
    gamma=0.0, learning_rate=0.01, max_depth=17, 
    min_child_weight=5,n_estimators=100,objective='multi:softprob')

votingCLF = VotingClassifier(estimators=[('knn', knn), ('ada', ada), ('xgb', xgb), ('dt', dt),('rf', rf)], voting='soft', weights=[5,7,10,6,5])
fit_and_evaluate_voting(votingCLF, enc_trainX, trainY, enc_testX, testY)
# Out:
# /home/numan947/anaconda3/envs/mldl/lib/python3.9/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# {'accuracy': 0.6996994355252547,
#  'classification_report': {'EARLY': {'precision': 0.7521871316001737,
#    'recall': 0.7735204976870315,
#    'f1-score': 0.7627046666352097,
#    'support': 31345.0},
#   'LATE': {'precision': 0.674373985339696,
#    'recall': 0.6698592650508209,
#    'f1-score': 0.672109043661592,
#    'support': 20464.0},
#   'ONTIME': {'precision': 0.6244566607005881,
#    'recall': 0.5958160526957794,
#    'f1-score': 0.6098002496878902,
#    'support': 16396.0},
#   'accuracy': 0.6996994355252547,
#   'macro avg': {'precision': 0.6836725925468192,
#    'recall': 0.6797319384778774,
#    'f1-score': 0.681537986661564,
#    'support': 68205.0},
#   'weighted avg': {'precision': 0.6981348330011851,
#    'recall': 0.6996994355252547,
#    'f1-score': 0.6987655177634208,
#    'support': 68205.0}},
#  'voting_classifier': VotingClassifier(estimators=[('knn', KNeighborsClassifier(n_neighbors=70)),
#                               ('ada',
#                                AdaBoostClassifier(learning_rate=0.8,
#                                                   n_estimators=200,
#                                                   random_state=947)),
#                               ('xgb',
#                                XGBClassifier(base_score=None, booster=None,
#                                              callbacks=None,
#                                              colsample_bylevel=None,
#                                              colsample_bynode=None,
#                                              colsample_bytree=0.7, device=None,
#                                              early_stopping_rounds=None,
#                                              enable_categorical=True,
#                                              ev...
#                                              max_delta_step=None, max_depth=17,
#                                              max_leaves=None, min_child_weight=5,
#                                              missing=nan,
#                                              monotone_constraints=None,
#                                              multi_strategy=None,
#                                              n_estimators=100, n_jobs=None,
#                                              num_parallel_tree=None,
#                                              objective='multi:softprob', ...)),
#                               ('dt',
#                                DecisionTreeClassifier(criterion='entropy',
#                                                       max_features='log2')),
#                               ('rf',
#                                RandomForestClassifier(criterion='entropy'))],
#                   voting='soft', weights=[5, 7, 10, 6, 5])}
